# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Daten darstellen mit verschiedenen Graphentypen
#
# https://matplotlib.org/stable/plot_types/basic/index.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # Hier das Unterpaket pyplot importieren

# %%
data = pd.read_csv("Data/AmazonStock.csv", thousands=",", decimal=".").drop(columns=["Date"])

# %%
data
# Out:
#             Open        High        Low       Close   Adj Close    Volume
# 0      12.929000   12.971500  12.725000   12.801000   12.801000  50278000
# 1      12.852500   13.074000  12.814000   13.015500   13.015500  48420000
# 2      12.937500   13.296500  12.895000   13.265000   13.265000  57498000
# 3      13.291000   13.369000  13.203000   13.324500   13.324500  49474000
# 4      13.349000   13.370000  13.050500   13.080500   13.080500  50496000
# ...          ...         ...        ...         ...         ...       ...
# 2514   98.410004   98.480003  95.699997   97.709999   97.709999  62388900
# 2515   98.139999  100.849998  98.000000  100.610001  100.610001  58597300
# 2516  100.449997  102.099998  98.610001   98.699997   98.699997  57475400
# 2517  100.430000  101.059998  97.620003   98.709999   98.709999  57559300
# 2518   98.070000   98.300003  96.400002   98.129997   98.129997  56095400
#
# [2519 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2519 entries, 0 to 2518
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2519 non-null   float64
#  1   High       2519 non-null   float64
#  2   Low        2519 non-null   float64
#  3   Close      2519 non-null   float64
#  4   Adj Close  2519 non-null   float64
#  5   Volume     2519 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 118.2 KB

# %%
data.plot()
# Out:
# <Axes: >

# %%
data["Open"].plot()  # X-Achse sollten Datumswerte sein
# Out:
# <Axes: >

# %%
data.set_index("Date", inplace=True)

# %%
data["Open"].plot(figsize=(12, 4), title="AMZN Stock Data")  # Mit figsize=(B, H) die Größe des Plots angeben
# Out:
# <Axes: title={'center': 'AMZN Stock Data'}, xlabel='Date'>

# %% [markdown]
# ### Indirekt Plotten mit Matplotlib selbst

# %%
plt.plot(data["Open"])
plt.title("AMZN Stock Data")
# Out:
# Text(0.5, 1.0, 'AMZN Stock Data')

# %%
plt.plot(data["Open"])
plt.plot(data["Close"])
plt.plot(data["High"])
plt.plot(data["Low"])

plt.legend(["Open", "Close", "High", "Low"], loc='lower right')
plt.show()  # Einen Graphen erstellen mit Vier Datenpunkten

# %%
plt.figure(figsize=(20, 10))

plt.subplot(2, 2, 1)  # Zeile 1, Spalte 1, PlotNummer 1
plt.plot(data["Open"])
plt.title("Open")

plt.subplot(2, 2, 2)
plt.plot(data["Close"])
plt.title("Close")

plt.subplot(2, 2, 3)
plt.plot(data["Low"])
plt.title("Low")

plt.subplot(2, 2, 4)
plt.plot(data["High"])
plt.title("High")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Globaler Modus vs. Objekt Orientierter Modus
#
# Globaler Modus: Plotten über plt direkt
#
# plt.plot, plt.title, plt.legend, ...

# %%
figure, achsen = plt.subplots(2, 2)

# %%
achsen[0, 0].plot(np.arange(100))
achsen[0, 1].plot(np.arange(50))
achsen[1, 0].plot(np.arange(75))
achsen[1, 1].plot(np.arange(25))

# %%
figure

# %%
achsen
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
fig, ((a1_1, a1_2), (a2_1, a2_2)) = plt.subplots(2, 2)

# %%
a1_1.plot(np.arange(100))
a1_2.plot(np.arange(50))
a2_1.plot(np.arange(75))
a2_2.plot(np.arange(25))

fig

# %% [markdown]
# Einzelnes Objekt mit OO-Modus

# %%
f, achse = plt.subplots(1, 1)

# %%
achse.plot(np.arange(75))

# %%
f

# %% [markdown]
# ### Balkendiagramm

# %%
plt.bar(np.arange(10), np.arange(10))
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(np.arange(10), np.random.random(10))
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(np.arange(10) + 0.25, np.random.random(10), width=0.5, edgecolor="black")
plt.bar(np.arange(10) - 0.25, np.random.random(10), width=0.5, edgecolor="black")
# plt.grid()
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Tortendiagramm

# %%
plt.pie(np.arange(5) + 1, frame=True, labels=np.arange(5) + 1)
plt.savefig("Pie.png")  # Diagramm speichern

None
