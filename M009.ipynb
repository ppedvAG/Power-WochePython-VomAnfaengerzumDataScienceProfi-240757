# %% [markdown]
# ## Reinforcement Learning
#
# Erlernen von einem Prozess, während des Prozesses
#
# Im Gegensatz zum konventionellen Machine Learning gibt es bei RL kein vorgegebenes Datenset
#
# Während des Prozesses wird das Datenset erzeugt
#
# z.B.: Roboter in der Realität laufen beibringen und währenddessen Hindernissen ausweichen

# %% [markdown]
# Begriffe:
#
# - Prozess
#     - Eine andauernde Aufgabe die kontinuierlich Daten erzeugt
#     - Diese Daten werden in das entsprechende Model hineingegeben
#
# - Umgebung
#     - Behälter für den Prozess + ML Model + Agenten + ...
#     - "Das Ganze"
#
# - Agent
#     - Kennt die Regeln des Prozesses
#     - Führt den Prozess aus (-> verantwortlich für das Lernen)

# %% [markdown]
# Packages: Gym(nasium), Stable Baselines 3

# %%
import gymnasium as gym

# %% [markdown]
# ### Vordefinierte Umgebungen
#
# Es gibt verschiedene vorgegebene Umgebungen zum Testen von RL
#
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
env = gym.make("CartPole-v1", render_mode="human")

# %% [markdown]
# ### Definition des Lernprozesses

# %% [markdown]
# Während des Prozesses sammelt der Agent Punkte
#
# Diese Punkte geben Auskunft über die Performance des Agenten (wie viele Aktionen der Agent richtig macht)

# %% [markdown]
# Inhalte einer Umgebung:
#
# - \_\_init__(): Setup der Umgebung
# - step(): Führt einen Schritt der Umgebung aus, und gibt alle möglichen Daten der Umgebung zurück
#     - Diese Daten können später im ML-Model verarbeitet werden
#     - state, reward, done, terminate, info
# - reset(): Setzt die Umgebung auf den Ausgangszustand zurück
# - render(): Zeichnet die Umgebung (falls möglich)
# - close(): Beendet die Umgebung

# %%
durchgaenge = 50
for x in range(durchgaenge):
    state = env.reset()  # Umgebung auf den Anfangszustand zurücksetzen
    score = 0  # Variable um die Performance des Algorithmus' zu speichern
    done = False  # Beschreibt, ob der Agent noch "im Spiel" ist

    while not done:
        env.render()
        # Action Space: Liste von möglichen Aktionen (hier links und rechts)
        # Random Action aus dem Action Space entnehmen
        action = env.action_space.sample()
        state, reward, done, term, info = env.step(action)
        score += reward  # reward: Gibt dem Agenten für korrekte Aktionen +Punkte, oder keine Punkte

    print(f"Durchgang {x + 1}, Score: {score}")
env.close()
# Out:
# Durchgang 1, Score: 22.0
# Durchgang 2, Score: 19.0
# Durchgang 3, Score: 20.0
# Durchgang 4, Score: 17.0
# Durchgang 5, Score: 28.0
# Durchgang 6, Score: 8.0
# Durchgang 7, Score: 12.0
# Durchgang 8, Score: 18.0
# Durchgang 9, Score: 28.0
# Durchgang 10, Score: 10.0
# Durchgang 11, Score: 21.0
# Durchgang 12, Score: 26.0
# Durchgang 13, Score: 27.0
# Durchgang 14, Score: 16.0
# Durchgang 15, Score: 23.0
# Durchgang 16, Score: 17.0
# Durchgang 17, Score: 15.0
# Durchgang 18, Score: 12.0
# Durchgang 19, Score: 17.0
# Durchgang 20, Score: 31.0
# Durchgang 21, Score: 23.0
# Durchgang 22, Score: 11.0
# Durchgang 23, Score: 15.0
# Durchgang 24, Score: 14.0
# Durchgang 25, Score: 19.0
# Durchgang 26, Score: 13.0
# Durchgang 27, Score: 14.0
# Durchgang 28, Score: 45.0
# Durchgang 29, Score: 21.0
# Durchgang 30, Score: 35.0
# Durchgang 31, Score: 19.0
# Durchgang 32, Score: 44.0
# Durchgang 33, Score: 11.0
# Durchgang 34, Score: 10.0
# Durchgang 35, Score: 16.0
# Durchgang 36, Score: 12.0
# Durchgang 37, Score: 12.0
# Durchgang 38, Score: 18.0
# Durchgang 39, Score: 22.0
# Durchgang 40, Score: 67.0
# Durchgang 41, Score: 44.0
# Durchgang 42, Score: 21.0
# Durchgang 43, Score: 20.0
# Durchgang 44, Score: 12.0
# Durchgang 45, Score: 16.0
# Durchgang 46, Score: 13.0
# Durchgang 47, Score: 18.0
# Durchgang 48, Score: 14.0
# Durchgang 49, Score: 17.0
# Durchgang 50, Score: 12.0

# %% [markdown]
# ### RL Modell trainieren

# %% [markdown]
# Random Actions sind für einen möglichst hohen Score etwas unpraktisch
#
# Wir wollen jetzt ein Model definieren, welches anhand des Game States die beste Action auswählt
#
# - observation_space: Die Daten, welche ausschlaggebend sind für die Umgebung
#     - Die beiden enthaltenen Arrays müssen als Bereiche interpretiert werden
#     - Der Observation Space wird für das ML verwendet
# - action_space: Mögliche Aktionen innerhalb der Umgebung

# %%
env.observation_space  # Box: Stellt X Bereiche dar, die Array Indizes korrenspondieren miteinander um Bereiche zu bilden
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
print(env.observation_space.low)
print(env.observation_space.high)
# Out:
# [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
# [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]

# %% [markdown]
# | Num | Observation           | Min                 | Max               |
# |-----|-----------------------|---------------------|-------------------|
# | 0   | Cart Position         | -4.8                | 4.8               |
# | 1   | Cart Velocity         | -Inf                | Inf               |
# | 2   | Pole Angle            | ~ -0.418 rad (-24°) | ~ 0.418 rad (24°) |
# | 3   | Pole Angular Velocity | -Inf                | Inf               |

# %%
env.action_space  # Discrete: X verschiedene Werte (hier 2)
# Out:
# Discrete(2)

# %% [markdown]
# | Num | Action                 |
# |-----|------------------------|
# | 0   | Push cart to the left  |
# | 1   | Push cart to the right |

# %% [markdown]
# ### Stable Baselines 3
#
# Wir können das Lernen auch per Tensorflow machen, aber SB3 hat einige vordefinierte Algorithmen
#
# - https://stable-baselines.readthedocs.io/en/master/guide/algos.html
#
# PPO: Proximal Policy Optimization
#
# - https://stable-baselines.readthedocs.io/en/master/modules/policies.html

# %%
from stable_baselines3 import PPO

# %%
env = gym.make("CartPole-v1")
model = PPO("MlpPolicy", env, verbose=1)  # MLP: Multilayer Perceptron -> Effektiv Dense Layers (2x64)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.6     |
# |    ep_rew_mean     | 22.6     |
# | time/              |          |
# |    fps             | 1753     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | 28.3        |
# | time/                   |             |
# |    fps                  | 994         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008974922 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000498   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.44        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 54.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.8        |
# |    ep_rew_mean          | 36.8        |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010378429 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0556      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.8        |
# |    ep_rew_mean          | 49.8        |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007893766 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 60.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.4         |
# |    ep_rew_mean          | 64.4         |
# | time/                   |              |
# |    fps                  | 760          |
# |    iterations           | 5            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0091920225 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.548        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0144      |
# |    value_loss           | 53.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.5       |
# |    ep_rew_mean          | 81.5       |
# | time/                   |            |
# |    fps                  | 749        |
# |    iterations           | 6          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00670297 |
# |    clip_fraction        | 0.0649     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.593     |
# |    explained_variance   | 0.332      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.2       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0112    |
# |    value_loss           | 73.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 97.3       |
# |    ep_rew_mean          | 97.3       |
# | time/                   |            |
# |    fps                  | 737        |
# |    iterations           | 7          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01312208 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.578     |
# |    explained_variance   | 0.564      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.7       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0115    |
# |    value_loss           | 57.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008416008 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 53.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 9            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0034785066 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.532        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 54.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008361628 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00764    |
# |    value_loss           | 53.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | 167          |
# | time/                   |              |
# |    fps                  | 680          |
# |    iterations           | 11           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0034767387 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 29           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | 186          |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 12           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0040223454 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.536        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.295        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 8.15         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 13          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005227439 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 4.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 222          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 14           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0046142437 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0.655        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.168        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 7.19e-06     |
# |    value_loss           | 3            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 245          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 634          |
# |    iterations           | 15           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0026901313 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0881       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000949    |
# |    value_loss           | 1.79         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 261         |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 16          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.001766023 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.517      |
# |    explained_variance   | 0.0104      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00708     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00135    |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 278           |
# |    ep_rew_mean          | 278           |
# | time/                   |               |
# |    fps                  | 622           |
# |    iterations           | 17            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00093544426 |
# |    clip_fraction        | 0.00737       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.523        |
# |    explained_variance   | -3.45e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0771        |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 0.000196      |
# |    value_loss           | 0.677         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 294          |
# |    ep_rew_mean          | 294          |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 18           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0018086531 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.00293      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00757      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000257    |
# |    value_loss           | 0.438        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | 312          |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 19           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0042391513 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.489       |
# |    explained_variance   | 0.0672       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00209      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 0.275        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | 327          |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 20           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0026406343 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | -0.00833     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00548     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000981    |
# |    value_loss           | 0.168        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 343         |
# |    ep_rew_mean          | 343         |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 21          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005054691 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.456      |
# |    explained_variance   | -0.0121     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00393     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.000789   |
# |    value_loss           | 0.103       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 359          |
# |    ep_rew_mean          | 359          |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 22           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0022480167 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | 0.0391       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0182       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000514    |
# |    value_loss           | 0.0665       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | 374          |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 23           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0036079152 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.454       |
# |    explained_variance   | 0.0103       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00754      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 0.0407       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 390          |
# |    ep_rew_mean          | 390          |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 24           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0013949117 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | -0.061       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00289     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.000408     |
# |    value_loss           | 0.0256       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | 409          |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 25           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0032798222 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.451       |
# |    explained_variance   | 0.0214       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00031     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 0.0166       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | 417          |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 26           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0036460506 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | -0.00662     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0187       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.0114       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 431         |
# |    ep_rew_mean          | 431         |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 27          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004243469 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00951    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00228    |
# |    value_loss           | 0.00693     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 446          |
# |    ep_rew_mean          | 446          |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 28           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0029797973 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.436       |
# |    explained_variance   | -0.0106      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00665      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 0.00457      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 461          |
# |    ep_rew_mean          | 461          |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 29           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0038757357 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.434       |
# |    explained_variance   | -0.0191      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00883      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.00311      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 470          |
# |    ep_rew_mean          | 470          |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 30           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0025178683 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.417       |
# |    explained_variance   | -0.0135      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00079      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000674    |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 483          |
# |    ep_rew_mean          | 483          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 31           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0011396185 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.424       |
# |    explained_variance   | -0.0508      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00627     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000173    |
# |    value_loss           | 0.00143      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 488          |
# |    ep_rew_mean          | 488          |
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 32           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0040871915 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | 0.0219       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0191      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 0.000992     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 496          |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 33           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0014859547 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | -0.00772     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00328      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000326    |
# |    value_loss           | 0.000634     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 499          |
# |    ep_rew_mean          | 499          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 34           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0027418528 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | -0.0375      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0133       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000167    |
# |    value_loss           | 0.000445     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 35          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.002544051 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | -0.0331     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0044     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -9.85e-05   |
# |    value_loss           | 0.000314    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 36           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0044154036 |
# |    clip_fraction        | 0.0647       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.00774      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0164      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 0.000241     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 37           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0047218865 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.415       |
# |    explained_variance   | -0.0489      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000546     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 0.000157     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 38          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006380879 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 0.000119    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 39           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0038455152 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | -0.0703      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0028       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 9.12e-05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 500        |
# | time/                   |            |
# |    fps                  | 585        |
# |    iterations           | 40         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00255588 |
# |    clip_fraction        | 0.0349     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.396     |
# |    explained_variance   | -0.0267    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00682    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.000118  |
# |    value_loss           | 6.02e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 41          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003736254 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | -0.111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00167     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 4.02e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 42           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0011568428 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | -0.0745      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000559    |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000193     |
# |    value_loss           | 3.29e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 43           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0056083715 |
# |    clip_fraction        | 0.0955       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.369       |
# |    explained_variance   | -0.166       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00564      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 2.04e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 44           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0042656697 |
# |    clip_fraction        | 0.0758       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | -0.247       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00659      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 1.49e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 45           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0035576485 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.376       |
# |    explained_variance   | -0.201       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.011        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 1.16e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 46          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003608031 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.338      |
# |    explained_variance   | -0.268      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00455    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 8.43e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 47           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0012106204 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.335       |
# |    explained_variance   | -0.41        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00573      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -6.91e-05    |
# |    value_loss           | 8.13e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 48           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0016663063 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.31        |
# |    explained_variance   | -0.531       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00591     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 5.11e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 49           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0012964697 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.308       |
# |    explained_variance   | -0.786       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00204     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000304     |
# |    value_loss           | 4.7e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 50           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0014330877 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.295       |
# |    explained_variance   | -0.919       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00446      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 2.48e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 51           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0034453298 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.297       |
# |    explained_variance   | -0.843       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000389     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 2.49e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 52           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0015700238 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.29        |
# |    explained_variance   | -1.16        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00451     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 1.56e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 53           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0043488382 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.284       |
# |    explained_variance   | -1.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00651      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 2.09e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 54           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0014499931 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | -2.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00682     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000613    |
# |    value_loss           | 9.08e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | 500           |
# ...
# |    iterations           | 81            |
# |    time_elapsed         | 286           |
# |    total_timesteps      | 165888        |
# | train/                  |               |
# |    approx_kl            | 0.00051136874 |
# |    clip_fraction        | 0.00835       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.242        |
# |    explained_variance   | -5.62         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00107      |
# |    n_updates            | 800           |
# |    policy_gradient_loss | 0.000594      |
# |    value_loss           | 1.75e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 82           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0067650527 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -3.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00589     |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 1.73e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | 500           |
# | time/                   |               |
# |    fps                  | 579           |
# |    iterations           | 83            |
# |    time_elapsed         | 293           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 0.00093907485 |
# |    clip_fraction        | 0.0181        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.246        |
# |    explained_variance   | -5.42         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00082       |
# |    n_updates            | 820           |
# |    policy_gradient_loss | 0.000614      |
# |    value_loss           | 2.43e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 84           |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0023783385 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | -4.23        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0124      |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 2.65e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 85           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0013747719 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | -5.2         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000674    |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 4.63e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 86           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0020950441 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -5.34        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 1.21e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 87          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.001468515 |
# |    clip_fraction        | 0.0121      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | -1.26       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.45e-05    |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.000501    |
# |    value_loss           | 4.19e-07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | 500           |
# | time/                   |               |
# |    fps                  | 579           |
# |    iterations           | 88            |
# |    time_elapsed         | 310           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 0.00061679486 |
# |    clip_fraction        | 0.00649       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.251        |
# |    explained_variance   | -1.28         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00141      |
# |    n_updates            | 870           |
# |    policy_gradient_loss | 0.000323      |
# |    value_loss           | 5.48e-06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 89          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.004132172 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | -1.54       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0084      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 2.39e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 90          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.004709494 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | -1.86       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 1.97e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 91           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0023476372 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -8.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0154      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 1.69e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 92          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.001738427 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.228      |
# |    explained_variance   | -2.47       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00366     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00126    |
# |    value_loss           | 1.28e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 93           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0017984675 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | -8.55        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000536     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -5.54e-05    |
# |    value_loss           | 2.19e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 94           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0034415196 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.275       |
# |    explained_variance   | -1.17        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00276      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000834    |
# |    value_loss           | 5.34e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 95           |
# |    time_elapsed         | 336          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0047492115 |
# |    clip_fraction        | 0.063        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.26        |
# |    explained_variance   | -1.53        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0124      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00488     |
# |    value_loss           | 2.89e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 96           |
# |    time_elapsed         | 339          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0016867965 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -1.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00292     |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.000476    |
# |    value_loss           | 8.9e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 97           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0034974816 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -2.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00233      |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.000709    |
# |    value_loss           | 9e-06        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 98           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0027677615 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | -3.01        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00355     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 0.000115     |
# |    value_loss           | 4.6e-07      |
# ------------------------------------------

# %%
model.save("Models/CartPoleModel")
# Out:
# C:\Users\lk3\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path 'Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
env = gym.make("CartPole-v1", render_mode="human")

# %%
model = PPO.load("../Models/CartPoleModel", env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
durchgaenge = 5
for x in range(durchgaenge):
    observation = env.reset()  # Umgebung auf den Anfangszustand zurücksetzen
    score = 0  # Variable um die Performance des Algorithmus' zu speichern
    done = False  # Beschreibt, ob der Agent noch "im Spiel" ist
    observation = observation[0].reshape(1, 4)

    while not (done or term):
        env.render()
        
        # Jetzt nehmen wir anstatt einer Random Action die Vorhersage des Models
        action, _ = model.predict(observation)
        if action.ndim == 1:
            action = action[0]
        
        observation, reward, done, term, info = env.step(action)
        score += reward  # reward: Gibt dem Agenten für korrekte Aktionen +Punkte, oder keine Punkte

    print(f"Durchgang {x + 1}, Score: {score}")
env.close()
# Out:
# Durchgang 1, Score: 500.0
# Durchgang 2, Score: 500.0
# Durchgang 3, Score: 500.0
# Durchgang 4, Score: 500.0
# Durchgang 5, Score: 500.0
