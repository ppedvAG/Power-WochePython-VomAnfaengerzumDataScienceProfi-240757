# %% [markdown]
# ## Eigene Umgebung
#
# Eine eigene Umgebung ist eine Klasse mit den Standardmethoden einer Umgebung (\_\_init__, step, reset, render, close)
#
# Wir benötigen zusätzlich auch Spaces (observation_space, action_space)

# %% [markdown]
# ### Typen von Spaces

# %%
from gymnasium.spaces import Discrete, Box, Dict, Tuple
import gymnasium as gym
import numpy as np

# %% [markdown]
# #### Discrete
#
# Liste befüllt mit X Werten (hier 3)
#
# Wird generell für den Action Space verwendet

# %%
Discrete(3)
# Out:
# Discrete(3)

# %%
d = Discrete(3)
for x in range(20):
    print(d.sample())
# Out:
# 1
# 1
# 0
# 1
# 2
# 2
# 0
# 1
# 1
# 0
# 2
# 0
# 0
# 1
# 1
# 2
# 2
# 2
# 0
# 1

# %% [markdown]
# #### Box
#
# Zwei Arrays welche kombiniert miteinander einen Bereich darstellen
#
# Wird generell für den Observation Space verwendet

# %%
Box(0, 100)  # Box mit einem Bereich
# Out:
# Box(0.0, 100.0, (1,), float32)

# %%
Box(0, 100, shape=(4,))
# Out:
# Box(0.0, 100.0, (4,), float32)

# %%
Box(0, 100, shape=(4,)).sample()
# Out:
# array([12.862288, 87.91389 , 67.61081 , 85.43166 ], dtype=float32)

# %%
Box(0, 100, shape=(4,), dtype=int).sample()
# Out:
# array([12, 19, 61, 81])

# %% [markdown]
# #### Tuple, Dict
#
# Tuple: Kombination von mehreren Spaces
#
# Dict: Kombination von mehreren Spaces (mit Namen)

# %%
Tuple((Box(0, 1), Box(0, 1)))
# Out:
# Tuple(Box(0.0, 1.0, (1,), float32), Box(0.0, 1.0, (1,), float32))

# %%
Tuple((Box(0, 1), Box(0, 1))).sample()
# Out:
# (array([0.13346805], dtype=float32), array([0.01115223], dtype=float32))

# %%
Dict({ "B1": Box(0, 1), "B2": Box(0, 1)})
# Out:
# Dict('B1': Box(0.0, 1.0, (1,), float32), 'B2': Box(0.0, 1.0, (1,), float32))

# %%
Dict({ "B1": Box(0, 1), "B2": Box(0, 1)})["B1"].sample()
# Out:
# array([0.21768107], dtype=float32)

# %% [markdown]
# ### Definition von eigener Umgebung
#
# Eine eigene Umgebung muss eine Klasse sein und von gym.Env erben
#
# Außerdem muss diese Umgebung die 4 Standardmethoden implementieren und action/observatio_space + State angeben
#
# Aufgabe des Fahrers: Die Geschwindigkeit zwischen 45km/h und 55km/h zu halten
# - Wenn der Fahrer im Bereich ist, bekommt er einen Punkt

# %%
from typing import Optional
class CarDriver(gym.Env):
    def __init__(self):
        self.action_space = Discrete(3)  # 3 verschiedene Aktionen (Nichts, Beschleunigen, Bremsen)
        self.observation_space = Box(0, 100, dtype=np.float32)  # Geschwindigkeitsgrenzen (zwischen 0 und 100)
        self.state = 50
        self.steps = 0
        self.maxLength = 60

    def step(self, action):
        # 0, Nichts: Geschwindigkeit += 0
        # 1, Beschleunigen: Geschwindigkeit += 3
        # 2, Bremsen: Geschwindigkeit -= 3
        if action == 1:
            self.state += 3
        if action == 2:
            self.state -= 3

        # reward vergeben
        if self.state >= 45 and self.state <= 55:
            reward = 1
        else:
            reward = 0

        self.steps += 1

        self.state += np.random.randint(-1, 1)  # Varianz der Fahrbahn (Bergauf, Bergab, Baustellen, Stau, ...)
        
        # state, reward, done, terminate, info
        # state muss immer ein Numpy Array sein
        return np.array([self.state], dtype=np.float32), reward, self.steps > self.maxLength, False, {}
    
    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        self.state = 50
        self.steps = 0
        return (np.array([self.state], dtype=np.float32), {})

    def render(self):
        pass

    def close(self):
        pass

# %% [markdown]
# ### EnvChecker
#
# Prüft, ob die Umgebung valide ist (-> korrekt implementiert wurde)

# %%
from stable_baselines3.common.env_checker import check_env

# %%
env = CarDriver()

# %%
check_env(env, warn=True)

# %%
durchgaenge = 10
for x in range(durchgaenge):
    state = env.reset()
    score = 0
    done = False

    while not done:
        action = env.action_space.sample()
        state, reward, done, term, info = env.step(action)
        score += reward
        # print(f"\tDurchgang {x + 1}, Geschwindigkeit: {state}")

    print(f"Durchgang {x + 1}, Score: {score}")
# Out:
# Durchgang 1, Score: 29
# Durchgang 2, Score: 13
# Durchgang 3, Score: 9
# Durchgang 4, Score: 7
# Durchgang 5, Score: 9
# Durchgang 6, Score: 5
# Durchgang 7, Score: 8
# Durchgang 8, Score: 1
# Durchgang 9, Score: 9
# Durchgang 10, Score: 10

# %%
from stable_baselines3 import PPO

# %%
env = CarDriver()
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(100_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61       |
# |    ep_rew_mean     | 13.3     |
# | time/              |          |
# |    fps             | 1501     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012602279 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 8.02        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0101014655 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0779       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 18.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 23.8        |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012466811 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.038       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 30          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 27.8        |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013194124 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.0272      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 30.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 678         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016640732 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.077       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 35          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 31.3         |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063033514 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 38.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 658         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009409844 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | -0.095      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0092     |
# |    value_loss           | 48.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 32.7         |
# | time/                   |              |
# |    fps                  | 645          |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0039283447 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | -0.0109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 43.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 10          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004248662 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 51.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 33.6         |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 11           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0075518424 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.866       |
# |    explained_variance   | 0.0951       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 43.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 32          |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 12          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007271585 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 50.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 35.1         |
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 13           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0087371245 |
# |    clip_fraction        | 0.0942       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.0614       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.5         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00901     |
# |    value_loss           | 49.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 36.3         |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 14           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0108117005 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00516     |
# |    value_loss           | 50.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 40.1         |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 15           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0056246547 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.1         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 56.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 39.3         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 16           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0045320243 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.734       |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.6         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000462    |
# |    value_loss           | 60.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 37.8        |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 17          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007595787 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.7        |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.5        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 64.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 39.1        |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 18          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002094447 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.1        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0008     |
# |    value_loss           | 58.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 42.1         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 19           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0018168371 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.2         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 67.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 39.9         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 20           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0045316056 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.8         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000378    |
# |    value_loss           | 66.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 38.9         |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 21           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0051549887 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.68        |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00981     |
# |    value_loss           | 51.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 39.8        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 22          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.003969269 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00855    |
# |    value_loss           | 65.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 42.5         |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 23           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0046555726 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.603       |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.7         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000261     |
# |    value_loss           | 77.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 43           |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 24           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0042769676 |
# |    clip_fraction        | 0.0537       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.8         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 68.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 43.1         |
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 25           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0010225658 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.6         |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.7         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000345    |
# |    value_loss           | 77.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 43           |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 26           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0012067703 |
# |    clip_fraction        | 0.0852       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.666       |
# |    explained_variance   | 0.29         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.1         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000687    |
# |    value_loss           | 72.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 43.6        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 27          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004148475 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 71          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 41.6         |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 28           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0037051162 |
# |    clip_fraction        | 0.0937       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.637       |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.5         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 73.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 44.1         |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 29           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0065269847 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.627       |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.5         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 58.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 44.6        |
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 30          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.003172284 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.5        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 70.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 47.5         |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 31           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0037645684 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.7         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.00299      |
# |    value_loss           | 78.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61         |
# |    ep_rew_mean          | 39.1       |
# | time/                   |            |
# |    fps                  | 549        |
# |    iterations           | 32         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.06365274 |
# |    clip_fraction        | 0.0589     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.585     |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.4       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.00293    |
# |    value_loss           | 76.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 33          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007671885 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.24        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 26.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 38.3         |
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 34           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0049853497 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.1         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 60.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 47.2         |
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 35           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0058009187 |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | 0.275        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.7         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.00803      |
# |    value_loss           | 77           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 48.8         |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 36           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0037778136 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.106        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.2         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 83.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 528          |
# |    iterations           | 37           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0019985978 |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.1         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00398      |
# |    value_loss           | 80.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 49.8         |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 38           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0035457388 |
# |    clip_fraction        | 0.0846       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.434       |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.3         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.0033       |
# |    value_loss           | 83.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 50.9         |
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 39           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0046770857 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.464       |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.8         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 86.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 51.6         |
# | time/                   |              |
# |    fps                  | 520          |
# |    iterations           | 40           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0012039496 |
# |    clip_fraction        | 0.056        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.0257       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.5         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00205      |
# |    value_loss           | 91.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 49.5        |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 41          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.019407084 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.0985      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.5        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0045      |
# |    value_loss           | 88.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 45.2         |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 42           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0047195847 |
# |    clip_fraction        | 0.0918       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.0481       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.3         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00216      |
# |    value_loss           | 82.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61         |
# |    ep_rew_mean          | 45         |
# | time/                   |            |
# |    fps                  | 511        |
# |    iterations           | 43         |
# |    time_elapsed         | 172        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.03763233 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.452     |
# |    explained_variance   | 0.319      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.1       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00572   |
# |    value_loss           | 78         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 49           |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 44           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0020222636 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.0802       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.1         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00407     |
# |    value_loss           | 93.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 52.5         |
# | time/                   |              |
# |    fps                  | 504          |
# |    iterations           | 45           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0006946562 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0.0397       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44           |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000543     |
# |    value_loss           | 95.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 53.5        |
# | time/                   |             |
# |    fps                  | 504         |
# |    iterations           | 46          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002974105 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | 0.0908      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000888    |
# |    value_loss           | 92.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 53.3        |
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 47          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020516362 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.486      |
# |    explained_variance   | 0.0433      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.3        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00287     |
# |    value_loss           | 97.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61         |
# |    ep_rew_mean          | 54.1       |
# | time/                   |            |
# |    fps                  | 501        |
# |    iterations           | 48         |
# |    time_elapsed         | 195        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00993944 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.404     |
# |    explained_variance   | 0.142      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.3       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00338   |
# |    value_loss           | 89.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61          |
# |    ep_rew_mean          | 52.4        |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 49          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007872778 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.0125      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00402     |
# |    value_loss           | 98.7        |
# -----------------------------------------

# %%
model.save("Models/CarDriver")

# %%
env = CarDriver()
model = PPO.load("Models/CarDriver", env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
durchgaenge = 10
for x in range(durchgaenge):
    observation = env.reset()  # Umgebung auf den Anfangszustand zurücksetzen
    score = 0  # Variable um die Performance des Algorithmus' zu speichern
    done = False  # Beschreibt, ob der Agent noch "im Spiel" ist
    observation = observation[0]

    while not (done or term):
        env.render()
        
        # Jetzt nehmen wir anstatt einer Random Action die Vorhersage des Models
        action, _ = model.predict(observation)
        if action.ndim == 1:
            action = action[0]
        
        observation, reward, done, term, info = env.step(action)
        score += reward  # reward: Gibt dem Agenten für korrekte Aktionen +Punkte, oder keine Punkte

    print(f"Durchgang {x + 1}, Score: {score}")
env.close()
# Out:
# Durchgang 1, Score: 47
# Durchgang 2, Score: 49
# Durchgang 3, Score: 55
# Durchgang 4, Score: 58
# Durchgang 5, Score: 61
# Durchgang 6, Score: 46
# Durchgang 7, Score: 50
# Durchgang 8, Score: 50
# Durchgang 9, Score: 50
# Durchgang 10, Score: 47
