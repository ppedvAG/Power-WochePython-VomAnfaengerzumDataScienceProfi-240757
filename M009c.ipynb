# %% [markdown]
# ## Doodle Jump Modell

# %%
import gymnasium as gym
import numpy as np
from DoodleJump import DoodleJumpGame

from typing import Optional
from gymnasium.spaces import Discrete, Box, Dict, Sequence
from stable_baselines3.common.env_checker import check_env

# %%
class DoodleJumpPlayer(gym.Env):
    def __init__(self):
        self.action_space = Discrete(2)
        self.observation_space = Dict({ "Platforms": Sequence(Box(0, 800, shape=(3,), dtype=np.int16), stack=True), "PlayerPosX": Box(0, 770, dtype=np.int16), "JumpTicks": Box(0, 150, dtype=np.int16) })
        self.game = DoodleJumpGame()
        self.state = self.getState()

    def step(self, action):
        self.game.step()
        
        previousPlayerPosX = self.game.playerPosX
        if action == 0:
            self.game.playerPosX -= 3
        elif action == 1:
            self.game.playerPosX += 3

        # näheste Plattform: in X Richtung erreichbar, mit den JumpTicks erreichbar
        leastDistance = 9999999
        closestPlatform = None
        for p in self.game.platforms:
            if p[1] - (self.game.playerPosY + (self.game.jumpTicks * 3)) < 0:
                continue
            if p[0] < self.game.playerPosX:
                distance = p[0] + p[2] - self.game.playerPosX
            elif p[0] > self.game.playerPosX:
                distance = p[0] - self.game.playerPosX
            else:
                distance = 0
                
            if distance < leastDistance:
                leastDistance = distance
                closestPlatform = p

        reward = 0
        if closestPlatform != None:
            if action == 0:
                targetX = closestPlatform[0] + closestPlatform[2]
                if self.game.playerPosX - targetX < previousPlayerPosX - targetX:
                    reward = 1
            if action == 1:
                targetX = closestPlatform[0]
                if targetX - self.game.playerPosX < targetX - previousPlayerPosX:
                    reward = 1
        
        return self.getState(), reward, self.game.death, self.game.death, { "ingame_score": self.game.highestHeight }

    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        self.close()
        self.game = DoodleJumpGame()
        self.state = self.getState()
        return (self.state, {})

    def render(self):
        self.game.setupUI()
        self.game.window.update()

    def close(self):
        if hasattr(self.game, "window"):
            try:
                self.game.window.destroy()
            except: pass

    def getState(self) -> dict:
        print(np.array(self.game.platforms))
        return dict({ "Platforms": np.array(self.game.platforms), "PlayerPosX": np.array(self.game.playerPosX, ndmin=1, dtype=np.int16), "JumpTicks": np.array(self.game.jumpTicks, ndmin=1, dtype=np.int16) })

# %%
env = DoodleJumpPlayer()
# Out:
# [[541  85 100]
#  [203 170 117]
#  [499 255 101]
#  [558 340 112]
#  [324 425 120]
#  [226 510 107]
#  [355 595 113]]

# %%
env.observation_space.sample()
# Out:
# OrderedDict([('JumpTicks', array([87], dtype=int16)),
#              ('Platforms',
#               array([[141, 440, 598],
#                      [ 58, 532, 200],
#                      [631, 178, 791],
#                      [128, 755,  50],
#                      [320, 680, 398],
#                      [793, 208,  90],
#                      [152, 386, 583],
#                      [333,  33, 329],
#                      [201, 675, 150]], dtype=int16)),
#              ('PlayerPosX', array([452], dtype=int16))])

# %%
check_env(env, warn=True)
# Out:
# [[ 85  85 100]
#  [227 170 115]
#  [362 255 112]
#  [360 340 114]
#  [540 425 112]
#  [140 510 109]
#  [192 595 111]]
# [[174  85 113]
#  [323 170 119]
#  [  6 255 100]
#  [385 340 118]
#  [145 425 104]
#  [553 510 100]
#  [ 37 595 115]]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\env_checker.py:296, in _check_returned_values(env, observation_space, action_space)
#     295 try:
# --> 296     _check_obs(obs[key], observation_space.spaces[key], "reset")
#     297 except AssertionError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\env_checker.py:214, in _check_obs(obs, observation_space, method_name)
#     212 if isinstance(obs, np.ndarray):
#     213     # check obs dimensions, dtype and bounds
# --> 214     assert observation_space.shape == obs.shape, (
#     215         f"The observation returned by the `{method_name}()` method does not match the shape "
#     216         f"of the given observation space {observation_space}. "
#     217         f"Expected: {observation_space.shape}, actual shape: {obs.shape}"
#     218     )
#     219     assert np.can_cast(obs.dtype, observation_space.dtype), (
#     220         f"The observation returned by the `{method_name}()` method does not match the data type (cannot cast) "
#     221         f"of the given observation space {observation_space}. "
#     222         f"Expected: {observation_space.dtype}, actual dtype: {obs.dtype}"
#     223     )
#
# AssertionError: The observation returned by the `reset()` method does not match the shape of the given observation space Sequence(Box(0, 800, (3,), int16), stack=True). Expected: None, actual shape: (7, 3)
#
# The above exception was the direct cause of the following exception:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 check_env(env, warn=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\env_checker.py:473, in check_env(env, warn, skip_render_check)
#     470     return
#     472 # ============ Check the returned values ===============
# --> 473 _check_returned_values(env, observation_space, action_space)
#     475 # ==== Check the render method and the declared render modes ====
#     476 if not skip_render_check:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\env_checker.py:298, in _check_returned_values(env, observation_space, action_space)
#     296             _check_obs(obs[key], observation_space.spaces[key], "reset")
#     297         except AssertionError as e:
# --> 298             raise AssertionError(f"Error while checking key={key}: " + str(e)) from e
#     299 else:
#     300     _check_obs(obs, observation_space, "reset")
#
# AssertionError: Error while checking key=Platforms: The observation returned by the `reset()` method does not match the shape of the given observation space Sequence(Box(0, 800, (3,), int16), stack=True). Expected: None, actual shape: (7, 3)

# %%
durchgaenge = 10
for x in range(durchgaenge):
    state = env.reset()
    score = 0
    done = False

    while not done:
        # env.render()
        action = env.action_space.sample()
        state, reward, done, term, info = env.step(action)
        score += reward
        # print(f"\tDurchgang {x + 1}, Geschwindigkeit: {state}")

    print(f"Durchgang {x + 1}, Reward: {score}, Peak: {info["ingame_score"]}")
# Out:
# [[ 47  85 119]
#  [574 170 101]
#  [588 255 109]
#  [667 340 107]
#  [261 425 120]
#  [ 84 510 111]
#  [375 595 109]]
# [[ 47  88 119]
#  [574 173 101]
#  [588 258 109]
#  [667 343 107]
#  [261 428 120]
#  [ 84 513 111]
#  [375 598 109]]
# [[ 47  91 119]
#  [574 176 101]
#  [588 261 109]
#  [667 346 107]
#  [261 431 120]
#  [ 84 516 111]
#  [375 601 109]]
# [[ 47  94 119]
#  [574 179 101]
#  [588 264 109]
#  [667 349 107]
#  [261 434 120]
#  [ 84 519 111]
#  [375 604 109]]
# [[ 47  97 119]
#  [574 182 101]
#  [588 267 109]
#  [667 352 107]
#  [261 437 120]
#  [ 84 522 111]
#  [375 607 109]]
# [[ 47 100 119]
#  [574 185 101]
#  [588 270 109]
#  [667 355 107]
#  [261 440 120]
#  [ 84 525 111]
#  [375 610 109]]
# [[ 47 103 119]
#  [574 188 101]
#  [588 273 109]
#  [667 358 107]
#  [261 443 120]
#  [ 84 528 111]
#  [375 613 109]]
# [[ 47 106 119]
#  [574 191 101]
#  [588 276 109]
#  [667 361 107]
#  [261 446 120]
#  [ 84 531 111]
#  [375 616 109]]
# [[ 47 109 119]
#  [574 194 101]
#  [588 279 109]
#  [667 364 107]
#  [261 449 120]
#  [ 84 534 111]
#  [375 619 109]]
# [[ 47 112 119]
#  [574 197 101]
#  [588 282 109]
#  [667 367 107]
#  [261 452 120]
#  [ 84 537 111]
#  [375 622 109]]
# [[ 47 115 119]
#  [574 200 101]
#  [588 285 109]
#  [667 370 107]
#  [261 455 120]
#  [ 84 540 111]
#  [375 625 109]]
# [[ 47 118 119]
#  [574 203 101]
#  [588 288 109]
#  [667 373 107]
#  [261 458 120]
#  [ 84 543 111]
#  [375 628 109]]
# [[ 47 121 119]
#  [574 206 101]
#  [588 291 109]
#  [667 376 107]
#  [261 461 120]
#  [ 84 546 111]
#  [375 631 109]]
# [[ 47 124 119]
#  [574 209 101]
#  [588 294 109]
#  [667 379 107]
#  [261 464 120]
#  [ 84 549 111]
#  [375 634 109]]
# [[ 47 127 119]
#  [574 212 101]
#  [588 297 109]
#  [667 382 107]
#  [261 467 120]
#  [ 84 552 111]
#  [375 637 109]]
# [[ 47 130 119]
#  [574 215 101]
#  [588 300 109]
#  [667 385 107]
#  [261 470 120]
#  [ 84 555 111]
#  [375 640 109]]
# [[ 47 133 119]
#  [574 218 101]
#  [588 303 109]
#  [667 388 107]
#  [261 473 120]
#  [ 84 558 111]
#  [375 643 109]]
# [[ 47 136 119]
#  [574 221 101]
#  [588 306 109]
#  [667 391 107]
#  [261 476 120]
#  [ 84 561 111]
#  [375 646 109]]
# [[ 47 139 119]
#  [574 224 101]
#  [588 309 109]
#  [667 394 107]
#  [261 479 120]
#  [ 84 564 111]
#  [375 649 109]]
# [[ 47 142 119]
#  [574 227 101]
#  [588 312 109]
#  [667 397 107]
#  [261 482 120]
#  [ 84 567 111]
#  [375 652 109]]
# [[ 47 145 119]
#  [574 230 101]
#  [588 315 109]
#  [667 400 107]
#  [261 485 120]
#  [ 84 570 111]
#  [375 655 109]]
# [[ 47 148 119]
#  [574 233 101]
#  [588 318 109]
#  [667 403 107]
#  [261 488 120]
#  [ 84 573 111]
#  [375 658 109]]
# [[ 47 151 119]
#  [574 236 101]
#  [588 321 109]
#  [667 406 107]
#  [261 491 120]
#  [ 84 576 111]
#  [375 661 109]]
# [[ 47 154 119]
#  [574 239 101]
#  [588 324 109]
#  [667 409 107]
#  [261 494 120]
#  [ 84 579 111]
#  [375 664 109]]
# [[ 47 157 119]
#  [574 242 101]
#  [588 327 109]
#  [667 412 107]
#  [261 497 120]
#  [ 84 582 111]
#  [375 667 109]]
# [[ 47 160 119]
#  [574 245 101]
#  [588 330 109]
#  [667 415 107]
#  [261 500 120]
#  [ 84 585 111]
#  [375 670 109]]
# [[ 47 163 119]
#  [574 248 101]
#  [588 333 109]
#  [667 418 107]
#  [261 503 120]
#  [ 84 588 111]
#  [375 673 109]]
# [[ 47 166 119]
#  [574 251 101]
#  [588 336 109]
#  [667 421 107]
#  [261 506 120]
#  [ 84 591 111]
#  [375 676 109]]
# [[ 47 169 119]
#  [574 254 101]
#  [588 339 109]
#  [667 424 107]
#  [261 509 120]
#  [ 84 594 111]
#  [375 679 109]]
# [[ 47 172 119]
#  [574 257 101]
#  [588 342 109]
#  [667 427 107]
#  [261 512 120]
#  [ 84 597 111]
#  [375 682 109]]
# [[ 47 175 119]
#  [574 260 101]
#  [588 345 109]
#  [667 430 107]
#  [261 515 120]
#  [ 84 600 111]
#  [375 685 109]]
# [[ 47 178 119]
#  [574 263 101]
#  [588 348 109]
#  [667 433 107]
#  [261 518 120]
#  [ 84 603 111]
#  [375 688 109]]
# [[ 47 181 119]
#  [574 266 101]
#  [588 351 109]
#  [667 436 107]
#  [261 521 120]
#  [ 84 606 111]
#  [375 691 109]]
# [[ 47 184 119]
#  [574 269 101]
#  [588 354 109]
#  [667 439 107]
#  [261 524 120]
#  [ 84 609 111]
#  [375 694 109]]
# [[ 47 187 119]
#  [574 272 101]
#  [588 357 109]
#  [667 442 107]
#  [261 527 120]
#  [ 84 612 111]
#  [375 697 109]]
# [[ 47 190 119]
#  [574 275 101]
#  [588 360 109]
#  [667 445 107]
#  [261 530 120]
#  [ 84 615 111]
#  [375 700 109]]
# [[ 47 193 119]
#  [574 278 101]
#  [588 363 109]
#  [667 448 107]
#  [261 533 120]
#  [ 84 618 111]
#  [375 703 109]]
# [[ 47 196 119]
#  [574 281 101]
#  [588 366 109]
#  [667 451 107]
#  [261 536 120]
#  [ 84 621 111]
#  [375 706 109]]
# [[ 47 199 119]
#  [574 284 101]
#  [588 369 109]
#  [667 454 107]
#  [261 539 120]
#  [ 84 624 111]
#  [375 709 109]]
# [[ 47 202 119]
#  [574 287 101]
#  [588 372 109]
#  [667 457 107]
#  [261 542 120]
#  [ 84 627 111]
#  [375 712 109]]
# [[ 47 205 119]
#  [574 290 101]
#  [588 375 109]
#  [667 460 107]
#  [261 545 120]
#  [ 84 630 111]
#  [375 715 109]]
# [[ 47 208 119]
#  [574 293 101]
#  [588 378 109]
#  [667 463 107]
#  [261 548 120]
#  [ 84 633 111]
#  [375 718 109]]
# [[ 47 211 119]
#  [574 296 101]
#  [588 381 109]
#  [667 466 107]
#  [261 551 120]
#  [ 84 636 111]
#  [375 721 109]]
# [[ 47 214 119]
#  [574 299 101]
#  [588 384 109]
#  [667 469 107]
#  [261 554 120]
#  [ 84 639 111]
#  [375 724 109]]
# [[ 47 217 119]
#  [574 302 101]
#  [588 387 109]
#  [667 472 107]
#  [261 557 120]
#  [ 84 642 111]
#  [375 727 109]]
# [[ 47 220 119]
#  [574 305 101]
#  [588 390 109]
#  [667 475 107]
#  [261 560 120]
#  [ 84 645 111]
#  [375 730 109]]
# [[ 47 223 119]
#  [574 308 101]
#  [588 393 109]
#  [667 478 107]
#  [261 563 120]
#  [ 84 648 111]
#  [375 733 109]]
# [[ 47 226 119]
#  [574 311 101]
#  [588 396 109]
#  [667 481 107]
#  [261 566 120]
#  [ 84 651 111]
#  [375 736 109]]
# [[ 47 229 119]
#  [574 314 101]
#  [588 399 109]
#  [667 484 107]
#  [261 569 120]
#  [ 84 654 111]
#  [375 739 109]]
# [[ 47 232 119]
#  [574 317 101]
#  [588 402 109]
#  [667 487 107]
#  [261 572 120]
#  [ 84 657 111]
#  [375 742 109]]
# [[ 47 235 119]
#  [574 320 101]
#  [588 405 109]
#  [667 490 107]
#  [261 575 120]
#  [ 84 660 111]
#  [375 745 109]]
# [[ 47 238 119]
#  [574 323 101]
#  [588 408 109]
#  [667 493 107]
#  [261 578 120]
#  [ 84 663 111]
#  [375 748 109]]
# [[ 47 241 119]
#  [574 326 101]
#  [588 411 109]
#  [667 496 107]
#  [261 581 120]
#  [ 84 666 111]
#  [375 751 109]]
# [[ 47 244 119]
#  [574 329 101]
#  [588 414 109]
#  [667 499 107]
#  [261 584 120]
#  [ 84 669 111]
#  [375 754 109]]
# [[ 47 247 119]
#  [574 332 101]
#  [588 417 109]
#  [667 502 107]
#  [261 587 120]
#  [ 84 672 111]
#  [375 757 109]]
# [[ 47 250 119]
#  [574 335 101]
#  [588 420 109]
#  [667 505 107]
#  [261 590 120]
#  [ 84 675 111]
#  [375 760 109]]
# [[ 47 253 119]
#  [574 338 101]
#  [588 423 109]
#  [667 508 107]
#  [261 593 120]
#  [ 84 678 111]
#  [375 763 109]]
# [[ 47 256 119]
#  [574 341 101]
#  [588 426 109]
#  [667 511 107]
#  [261 596 120]
#  [ 84 681 111]
#  [375 766 109]]
# [[ 47 259 119]
#  [574 344 101]
#  [588 429 109]
#  [667 514 107]
#  [261 599 120]
#  [ 84 684 111]
#  [375 769 109]]
# [[ 47 262 119]
#  [574 347 101]
#  [588 432 109]
#  [667 517 107]
#  [261 602 120]
#  [ 84 687 111]
#  [375 772 109]]
# [[ 47 265 119]
#  [574 350 101]
#  [588 435 109]
#  [667 520 107]
#  [261 605 120]
#  [ 84 690 111]
#  [375 775 109]]
# [[ 47 268 119]
#  [574 353 101]
#  [588 438 109]
#  [667 523 107]
#  [261 608 120]
#  [ 84 693 111]
#  [375 778 109]]
# [[ 47 271 119]
#  [574 356 101]
#  [588 441 109]
#  [667 526 107]
#  [261 611 120]
#  [ 84 696 111]
#  [375 781 109]]
# [[ 47 274 119]
#  [574 359 101]
#  [588 444 109]
#  [667 529 107]
#  [261 614 120]
#  [ 84 699 111]
#  [375 784 109]]
# [[ 47 277 119]
#  [574 362 101]
#  [588 447 109]
#  [667 532 107]
#  [261 617 120]
#  [ 84 702 111]
#  [375 787 109]]
# [[ 47 280 119]
#  [574 365 101]
#  [588 450 109]
#  [667 535 107]
#  [261 620 120]
#  [ 84 705 111]
#  [375 790 109]]
# [[ 47 283 119]
#  [574 368 101]
#  [588 453 109]
#  [667 538 107]
#  [261 623 120]
#  [ 84 708 111]
#  [375 793 109]]
# [[ 47 286 119]
#  [574 371 101]
#  [588 456 109]
#  [667 541 107]
#  [261 626 120]
#  [ 84 711 111]
#  [375 796 109]]
# [[ 47 289 119]
#  [574 374 101]
#  [588 459 109]
#  [667 544 107]
#  [261 629 120]
#  [ 84 714 111]
#  [375 799 109]]
# [[ 47 292 119]
#  [574 377 101]
#  [588 462 109]
#  [667 547 107]
#  [261 632 120]
#  [ 84 717 111]
#  [375 802 109]]
# [[ 47 295 119]
#  [574 380 101]
#  [588 465 109]
#  [667 550 107]
#  [261 635 120]
#  [ 84 720 111]
#  [375 805 109]]
# [[ 47 298 119]
#  [574 383 101]
#  [588 468 109]
#  [667 553 107]
#  [261 638 120]
#  [ 84 723 111]
#  [375 808 109]]
# [[ 47 301 119]
#  [574 386 101]
#  [588 471 109]
#  [667 556 107]
#  [261 641 120]
#  [ 84 726 111]
#  [375 811 109]]
# [[ 47 304 119]
#  [574 389 101]
#  [588 474 109]
#  [667 559 107]
#  [261 644 120]
#  [ 84 729 111]
#  [375 814 109]]
# [[ 47 307 119]
#  [574 392 101]
#  [588 477 109]
#  [667 562 107]
#  [261 647 120]
#  [ 84 732 111]
#  [375 817 109]]
# [[ 47 310 119]
#  [574 395 101]
#  [588 480 109]
#  [667 565 107]
#  [261 650 120]
#  [ 84 735 111]
#  [375 820 109]]
# [[ 47 313 119]
#  [574 398 101]
#  [588 483 109]
#  [667 568 107]
#  [261 653 120]
#  [ 84 738 111]
#  [375 823 109]]
# [[ 47 316 119]
#  [574 401 101]
#  [588 486 109]
#  [667 571 107]
#  [261 656 120]
#  [ 84 741 111]
#  [375 826 109]]
# [[ 47 319 119]
#  [574 404 101]
#  [588 489 109]
#  [667 574 107]
#  [261 659 120]
#  [ 84 744 111]
#  [375 829 109]]
# [[ 47 322 119]
#  [574 407 101]
#  [588 492 109]
#  [667 577 107]
#  [261 662 120]
#  [ 84 747 111]
#  [375 832 109]]
# [[ 47 325 119]
#  [574 410 101]
#  [588 495 109]
#  [667 580 107]
#  [261 665 120]
#  [ 84 750 111]
#  [375 835 109]]
# [[ 47 328 119]
#  [574 413 101]
#  [588 498 109]
#  [667 583 107]
#  [261 668 120]
#  [ 84 753 111]
#  [375 838 109]]
# [[ 47 331 119]
#  [574 416 101]
#  [588 501 109]
#  [667 586 107]
#  [261 671 120]
#  [ 84 756 111]
#  [375 841 109]]
# [[ 47 334 119]
#  [574 419 101]
#  [588 504 109]
#  [667 589 107]
#  [261 674 120]
#  [ 84 759 111]
#  [375 844 109]]
# [[ 47 337 119]
#  [574 422 101]
#  [588 507 109]
#  [667 592 107]
#  [261 677 120]
#  [ 84 762 111]
#  [375 847 109]]
# [[ 47 340 119]
#  [574 425 101]
#  [588 510 109]
#  [667 595 107]
#  [261 680 120]
#  [ 84 765 111]
#  [375 850 109]]
# [[ 47 343 119]
#  [574 428 101]
#  [588 513 109]
#  [667 598 107]
#  [261 683 120]
#  [ 84 768 111]
#  [375 853 109]]
# [[ 47 346 119]
#  [574 431 101]
#  [588 516 109]
#  [667 601 107]
#  [261 686 120]
#  [ 84 771 111]
#  [375 856 109]]
# [[ 47 349 119]
#  [574 434 101]
#  [588 519 109]
#  [667 604 107]
#  [261 689 120]
#  [ 84 774 111]
#  [375 859 109]]
# [[ 47 352 119]
#  [574 437 101]
#  [588 522 109]
#  [667 607 107]
#  [261 692 120]
#  [ 84 777 111]
#  [375 862 109]]
# [[ 47 355 119]
#  [574 440 101]
#  [588 525 109]
#  [667 610 107]
#  [261 695 120]
#  [ 84 780 111]
#  [375 865 109]]
# [[ 47 358 119]
#  [574 443 101]
#  [588 528 109]
#  [667 613 107]
#  [261 698 120]
#  [ 84 783 111]
#  [375 868 109]]
# [[ 47 361 119]
#  [574 446 101]
#  [588 531 109]
#  [667 616 107]
#  [261 701 120]
#  [ 84 786 111]
#  [375 871 109]]
# [[ 47 364 119]
#  [574 449 101]
#  [588 534 109]
#  [667 619 107]
#  [261 704 120]
#  [ 84 789 111]
#  [375 874 109]]
# [[ 47 367 119]
#  [574 452 101]
#  [588 537 109]
#  [667 622 107]
#  [261 707 120]
#  [ 84 792 111]
#  [375 877 109]]
# [[ 47 370 119]
#  [574 455 101]
#  [588 540 109]
#  [667 625 107]
#  [261 710 120]
#  [ 84 795 111]
#  [375 880 109]]
# [[ 47 373 119]
#  [574 458 101]
#  [588 543 109]
#  [667 628 107]
#  [261 713 120]
#  [ 84 798 111]
#  [375 883 109]]
# [[ 47 376 119]
#  [574 461 101]
#  [588 546 109]
#  [667 631 107]
#  [261 716 120]
#  [ 84 801 111]
#  [375 886 109]]
# [[ 47 379 119]
#  [574 464 101]
#  [588 549 109]
#  [667 634 107]
#  [261 719 120]
#  [ 84 804 111]
#  [375 889 109]]
# [[ 47 382 119]
#  [574 467 101]
#  [588 552 109]
#  [667 637 107]
#  [261 722 120]
#  [ 84 807 111]
#  [375 892 109]]
# [[ 47 385 119]
#  [574 470 101]
#  [588 555 109]
#  [667 640 107]
#  [261 725 120]
#  [ 84 810 111]
#  [375 895 109]]
# [[ 47 388 119]
#  [574 473 101]
#  [588 558 109]
#  [667 643 107]
#  [261 728 120]
#  [ 84 813 111]
#  [375 898 109]]
# [[ 47 391 119]
#  [574 476 101]
#  [588 561 109]
#  [667 646 107]
#  [261 731 120]
#  [ 84 816 111]
#  [375 901 109]]
# [[ 47 394 119]
#  [574 479 101]
#  [588 564 109]
#  [667 649 107]
#  [261 734 120]
#  [ 84 819 111]
#  [375 904 109]]
# [[ 47 397 119]
#  [574 482 101]
#  [588 567 109]
#  [667 652 107]
#  [261 737 120]
#  [ 84 822 111]
#  [375 907 109]]
# [[ 47 400 119]
#  [574 485 101]
#  [588 570 109]
#  [667 655 107]
#  [261 740 120]
#  [ 84 825 111]
#  [375 910 109]]
# [[ 47 403 119]
#  [574 488 101]
#  [588 573 109]
#  [667 658 107]
#  [261 743 120]
#  [ 84 828 111]
#  [375 913 109]]
# [[ 47 406 119]
#  [574 491 101]
#  [588 576 109]
#  [667 661 107]
#  [261 746 120]
#  [ 84 831 111]
#  [375 916 109]]
# [[ 47 409 119]
#  [574 494 101]
#  [588 579 109]
#  [667 664 107]
#  [261 749 120]
#  [ 84 834 111]
#  [375 919 109]]
# [[ 47 412 119]
#  [574 497 101]
#  [588 582 109]
#  [667 667 107]
#  [261 752 120]
#  [ 84 837 111]
#  [375 922 109]]
# [[ 47 415 119]
#  [574 500 101]
#  [588 585 109]
#  [667 670 107]
#  [261 755 120]
#  [ 84 840 111]
#  [375 925 109]]
# [[ 47 418 119]
#  [574 503 101]
#  [588 588 109]
#  [667 673 107]
#  [261 758 120]
#  [ 84 843 111]
#  [375 928 109]]
# [[ 47 421 119]
#  [574 506 101]
#  [588 591 109]
#  [667 676 107]
#  [261 761 120]
#  [ 84 846 111]
#  [375 931 109]]
# [[ 47 424 119]
#  [574 509 101]
#  [588 594 109]
#  [667 679 107]
#  [261 764 120]
#  [ 84 849 111]
#  [375 934 109]]
# [[ 47 427 119]
#  [574 512 101]
#  [588 597 109]
#  [667 682 107]
#  [261 767 120]
#  [ 84 852 111]
#  [375 937 109]]
# [[ 47 430 119]
#  [574 515 101]
#  [588 600 109]
#  [667 685 107]
#  [261 770 120]
#  [ 84 855 111]
#  [375 940 109]]
# [[ 47 433 119]
#  [574 518 101]
#  [588 603 109]
#  [667 688 107]
#  [261 773 120]
#  [ 84 858 111]
#  [375 943 109]]
# [[ 47 436 119]
#  [574 521 101]
#  [588 606 109]
#  [667 691 107]
#  [261 776 120]
#  [ 84 861 111]
#  [375 946 109]]
# [[ 47 439 119]
#  [574 524 101]
#  [588 609 109]
#  [667 694 107]
#  [261 779 120]
#  [ 84 864 111]
#  [375 949 109]]
# [[ 47 442 119]
#  [574 527 101]
#  [588 612 109]
#  [667 697 107]
#  [261 782 120]
#  [ 84 867 111]
#  [375 952 109]]
# [[ 47 445 119]
#  [574 530 101]
#  [588 615 109]
#  [667 700 107]
#  [261 785 120]
#  [ 84 870 111]
#  [375 955 109]]
# [[ 47 448 119]
#  [574 533 101]
#  [588 618 109]
#  [667 703 107]
#  [261 788 120]
#  [ 84 873 111]
#  [375 958 109]]
# [[ 47 451 119]
#  [574 536 101]
#  [588 621 109]
#  [667 706 107]
#  [261 791 120]
#  [ 84 876 111]
#  [375 961 109]]
# [[ 47 454 119]
#  [574 539 101]
#  [588 624 109]
#  [667 709 107]
#  [261 794 120]
#  [ 84 879 111]
#  [375 964 109]]
# [[ 47 457 119]
#  [574 542 101]
#  [588 627 109]
#  [667 712 107]
#  [261 797 120]
#  [ 84 882 111]
#  [375 967 109]]
# [[ 47 460 119]
#  [574 545 101]
#  [588 630 109]
#  [667 715 107]
#  [261 800 120]
#  [ 84 885 111]
#  [375 970 109]]
# [[ 47 463 119]
#  [574 548 101]
#  [588 633 109]
#  [667 718 107]
#  [261 803 120]
#  [ 84 888 111]
#  [375 973 109]]
# [[ 47 466 119]
#  [574 551 101]
#  [588 636 109]
#  [667 721 107]
#  [261 806 120]
#  [ 84 891 111]
#  [375 976 109]]
# [[ 47 469 119]
#  [574 554 101]
#  [588 639 109]
#  [667 724 107]
#  [261 809 120]
#  [ 84 894 111]
#  [375 979 109]]
# [[ 47 472 119]
#  [574 557 101]
#  [588 642 109]
#  [667 727 107]
#  [261 812 120]
#  [ 84 897 111]
#  [375 982 109]]
# [[ 47 475 119]
#  [574 560 101]
#  [588 645 109]
#  [667 730 107]
#  [261 815 120]
#  [ 84 900 111]
#  [375 985 109]]
# [[ 47 478 119]
#  [574 563 101]
#  [588 648 109]
#  [667 733 107]
#  [261 818 120]
#  [ 84 903 111]
#  [375 988 109]]
# [[ 47 481 119]
#  [574 566 101]
#  [588 651 109]
#  [667 736 107]
#  [261 821 120]
#  [ 84 906 111]
#  [375 991 109]]
# [[ 47 484 119]
#  [574 569 101]
#  [588 654 109]
#  [667 739 107]
#  [261 824 120]
#  [ 84 909 111]
#  [375 994 109]]
# [[ 47 487 119]
#  [574 572 101]
#  [588 657 109]
#  [667 742 107]
#  [261 827 120]
#  [ 84 912 111]
#  [375 997 109]]
# [[  47  490  119]
#  [ 574  575  101]
#  [ 588  660  109]
#  [ 667  745  107]
#  [ 261  830  120]
#  [  84  915  111]
#  [ 375 1000  109]]
# [[  47  493  119]
#  [ 574  578  101]
#  [ 588  663  109]
#  [ 667  748  107]
#  [ 261  833  120]
#  [  84  918  111]
#  [ 375 1003  109]]
# [[  47  496  119]
#  [ 574  581  101]
#  [ 588  666  109]
#  [ 667  751  107]
#  [ 261  836  120]
#  [  84  921  111]
#  [ 375 1006  109]]
# [[  47  499  119]
#  [ 574  584  101]
#  [ 588  669  109]
#  [ 667  754  107]
#  [ 261  839  120]
#  [  84  924  111]
#  [ 375 1009  109]]
# [[  47  502  119]
#  [ 574  587  101]
#  [ 588  672  109]
#  [ 667  757  107]
#  [ 261  842  120]
#  [  84  927  111]
#  [ 375 1012  109]]
# [[  47  505  119]
#  [ 574  590  101]
#  [ 588  675  109]
#  [ 667  760  107]
#  [ 261  845  120]
#  [  84  930  111]
#  [ 375 1015  109]]
# [[  47  508  119]
#  [ 574  593  101]
#  [ 588  678  109]
#  [ 667  763  107]
#  [ 261  848  120]
#  [  84  933  111]
#  [ 375 1018  109]]
# [[  47  511  119]
#  [ 574  596  101]
#  [ 588  681  109]
#  [ 667  766  107]
#  [ 261  851  120]
#  [  84  936  111]
#  [ 375 1021  109]]
# [[  47  514  119]
#  [ 574  599  101]
#  [ 588  684  109]
#  [ 667  769  107]
#  [ 261  854  120]
#  [  84  939  111]
#  [ 375 1024  109]]
# [[  47  517  119]
#  [ 574  602  101]
#  [ 588  687  109]
#  [ 667  772  107]
#  [ 261  857  120]
#  [  84  942  111]
#  [ 375 1027  109]]
# [[  47  520  119]
#  [ 574  605  101]
#  [ 588  690  109]
#  [ 667  775  107]
#  [ 261  860  120]
#  [  84  945  111]
#  [ 375 1030  109]]
# [[  47  523  119]
#  [ 574  608  101]
#  [ 588  693  109]
#  [ 667  778  107]
#  [ 261  863  120]
#  [  84  948  111]
#  [ 375 1033  109]]
# [[  47  526  119]
#  [ 574  611  101]
#  [ 588  696  109]
#  [ 667  781  107]
#  [ 261  866  120]
#  [  84  951  111]
#  [ 375 1036  109]]
# [[  47  529  119]
#  [ 574  614  101]
#  [ 588  699  109]
#  [ 667  784  107]
#  [ 261  869  120]
#  [  84  954  111]
#  [ 375 1039  109]]
# [[  47  532  119]
#  [ 574  617  101]
#  [ 588  702  109]
#  [ 667  787  107]
#  [ 261  872  120]
#  [  84  957  111]
#  [ 375 1042  109]]
# [[  47  535  119]
#  [ 574  620  101]
#  [ 588  705  109]
#  [ 667  790  107]
#  [ 261  875  120]
#  [  84  960  111]
#  [ 375 1045  109]]
# [[  47  538  119]
#  [ 574  623  101]
#  [ 588  708  109]
#  [ 667  793  107]
#  [ 261  878  120]
#  [  84  963  111]
#  [ 375 1048  109]]
# [[  47  541  119]
#  [ 574  626  101]
#  [ 588  711  109]
#  [ 667  796  107]
#  [ 261  881  120]
#  [  84  966  111]
#  [ 375 1051  109]]
# [[  47  544  119]
#  [ 574  629  101]
#  [ 588  714  109]
#  [ 667  799  107]
#  [ 261  884  120]
#  [  84  969  111]
#  [ 375 1054  109]]
# [[  47  547  119]
#  [ 574  632  101]
#  [ 588  717  109]
#  [ 667  802  107]
#  [ 261  887  120]
#  [  84  972  111]
#  [ 375 1057  109]]
# [[  47  550  119]
#  [ 574  635  101]
#  [ 588  720  109]
#  [ 667  805  107]
#  [ 261  890  120]
#  [  84  975  111]
#  [ 375 1060  109]]
# [[  47  553  119]
#  [ 574  638  101]
#  [ 588  723  109]
#  [ 667  808  107]
#  [ 261  893  120]
#  [  84  978  111]
#  [ 375 1063  109]]
# [[  47  556  119]
#  [ 574  641  101]
#  [ 588  726  109]
#  [ 667  811  107]
#  [ 261  896  120]
#  [  84  981  111]
#  [ 375 1066  109]]
# [[  47  559  119]
#  [ 574  644  101]
#  [ 588  729  109]
#  [ 667  814  107]
#  [ 261  899  120]
#  [  84  984  111]
#  [ 375 1069  109]]
# [[  47  562  119]
#  [ 574  647  101]
#  [ 588  732  109]
#  [ 667  817  107]
#  [ 261  902  120]
#  [  84  987  111]
#  [ 375 1072  109]]
# [[  47  565  119]
#  [ 574  650  101]
#  [ 588  735  109]
#  [ 667  820  107]
#  [ 261  905  120]
#  [  84  990  111]
#  [ 375 1075  109]]
# [[  47  568  119]
#  [ 574  653  101]
#  [ 588  738  109]
#  [ 667  823  107]
#  [ 261  908  120]
#  [  84  993  111]
#  [ 375 1078  109]]
# [[  47  571  119]
#  [ 574  656  101]
#  [ 588  741  109]
#  [ 667  826  107]
#  [ 261  911  120]
#  [  84  996  111]
#  [ 375 1081  109]]
# [[  47  574  119]
#  [ 574  659  101]
#  [ 588  744  109]
#  [ 667  829  107]
#  [ 261  914  120]
#  [  84  999  111]
#  [ 375 1084  109]]
# [[  47  577  119]
#  [ 574  662  101]
#  [ 588  747  109]
#  [ 667  832  107]
#  [ 261  917  120]
#  [  84 1002  111]
#  [ 375 1087  109]]
# [[  47  580  119]
#  [ 574  665  101]
#  [ 588  750  109]
#  [ 667  835  107]
#  [ 261  920  120]
#  [  84 1005  111]
#  [ 375 1090  109]]
# [[  47  583  119]
#  [ 574  668  101]
#  [ 588  753  109]
#  [ 667  838  107]
#  [ 261  923  120]
#  [  84 1008  111]
#  [ 375 1093  109]]
# [[  47  586  119]
#  [ 574  671  101]
#  [ 588  756  109]
#  [ 667  841  107]
#  [ 261  926  120]
#  [  84 1011  111]
#  [ 375 1096  109]]
# [[  47  589  119]
#  [ 574  674  101]
#  [ 588  759  109]
#  [ 667  844  107]
#  [ 261  929  120]
#  [  84 1014  111]
#  [ 375 1099  109]]
# [[  47  592  119]
#  [ 574  677  101]
#  [ 588  762  109]
#  [ 667  847  107]
#  [ 261  932  120]
#  [  84 1017  111]
#  [ 375 1102  109]]
# [[  47  595  119]
#  [ 574  680  101]
#  [ 588  765  109]
#  [ 667  850  107]
#  [ 261  935  120]
#  [  84 1020  111]
#  [ 375 1105  109]]
# [[  47  598  119]
#  [ 574  683  101]
#  [ 588  768  109]
#  [ 667  853  107]
#  [ 261  938  120]
#  [  84 1023  111]
#  [ 375 1108  109]]
# [[  47  601  119]
#  [ 574  686  101]
#  [ 588  771  109]
#  [ 667  856  107]
#  [ 261  941  120]
#  [  84 1026  111]
#  [ 375 1111  109]]
# [[  47  604  119]
#  [ 574  689  101]
#  [ 588  774  109]
#  [ 667  859  107]
#  [ 261  944  120]
#  [  84 1029  111]
#  [ 375 1114  109]]
# [[  47  607  119]
#  [ 574  692  101]
#  [ 588  777  109]
#  [ 667  862  107]
#  [ 261  947  120]
#  [  84 1032  111]
#  [ 375 1117  109]]
# [[  47  610  119]
#  [ 574  695  101]
#  [ 588  780  109]
#  [ 667  865  107]
#  [ 261  950  120]
#  [  84 1035  111]
#  [ 375 1120  109]]
# [[  47  613  119]
#  [ 574  698  101]
#  [ 588  783  109]
#  [ 667  868  107]
#  [ 261  953  120]
#  [  84 1038  111]
#  [ 375 1123  109]]
# [[  47  616  119]
#  [ 574  701  101]
#  [ 588  786  109]
#  [ 667  871  107]
#  [ 261  956  120]
#  [  84 1041  111]
#  [ 375 1126  109]]
# [[  47  619  119]
#  [ 574  704  101]
#  [ 588  789  109]
#  [ 667  874  107]
#  [ 261  959  120]
#  [  84 1044  111]
#  [ 375 1129  109]]
# [[  47  622  119]
#  [ 574  707  101]
#  [ 588  792  109]
#  [ 667  877  107]
#  [ 261  962  120]
#  [  84 1047  111]
#  [ 375 1132  109]]
# [[  47  625  119]
#  [ 574  710  101]
#  [ 588  795  109]
#  [ 667  880  107]
#  [ 261  965  120]
#  [  84 1050  111]
#  [ 375 1135  109]]
# [[  47  628  119]
#  [ 574  713  101]
#  [ 588  798  109]
#  [ 667  883  107]
#  [ 261  968  120]
#  [  84 1053  111]
#  [ 375 1138  109]]
# [[  47  631  119]
#  [ 574  716  101]
#  [ 588  801  109]
#  [ 667  886  107]
#  [ 261  971  120]
#  [  84 1056  111]
#  [ 375 1141  109]]
# [[  47  634  119]
#  [ 574  719  101]
#  [ 588  804  109]
#  [ 667  889  107]
#  [ 261  974  120]
#  [  84 1059  111]
#  [ 375 1144  109]]
# [[  47  637  119]
#  [ 574  722  101]
#  [ 588  807  109]
#  [ 667  892  107]
#  [ 261  977  120]
#  [  84 1062  111]
#  [ 375 1147  109]]
# [[  47  640  119]
#  [ 574  725  101]
#  [ 588  810  109]
#  [ 667  895  107]
#  [ 261  980  120]
#  [  84 1065  111]
#  [ 375 1150  109]]
# [[  47  643  119]
#  [ 574  728  101]
#  [ 588  813  109]
#  [ 667  898  107]
#  [ 261  983  120]
#  [  84 1068  111]
#  [ 375 1153  109]]
# [[  47  646  119]
#  [ 574  731  101]
#  [ 588  816  109]
#  [ 667  901  107]
#  [ 261  986  120]
#  [  84 1071  111]
#  [ 375 1156  109]]
# [[  47  649  119]
#  [ 574  734  101]
#  [ 588  819  109]
#  [ 667  904  107]
#  [ 261  989  120]
#  [  84 1074  111]
#  [ 375 1159  109]]
# [[  47  652  119]
#  [ 574  737  101]
#  [ 588  822  109]
#  [ 667  907  107]
#  [ 261  992  120]
#  [  84 1077  111]
#  [ 375 1162  109]]
# [[  47  655  119]
#  [ 574  740  101]
#  [ 588  825  109]
#  [ 667  910  107]
#  [ 261  995  120]
#  [  84 1080  111]
#  [ 375 1165  109]]
# [[  47  658  119]
#  [ 574  743  101]
#  [ 588  828  109]
#  [ 667  913  107]
#  [ 261  998  120]
#  [  84 1083  111]
#  [ 375 1168  109]]
# [[  47  661  119]
#  [ 574  746  101]
#  [ 588  831  109]
#  [ 667  916  107]
#  [ 261 1001  120]
#  [  84 1086  111]
#  [ 375 1171  109]]
# [[  47  664  119]
#  [ 574  749  101]
#  [ 588  834  109]
#  [ 667  919  107]
#  [ 261 1004  120]
#  [  84 1089  111]
#  [ 375 1174  109]]
# [[  47  667  119]
#  [ 574  752  101]
#  [ 588  837  109]
#  [ 667  922  107]
#  [ 261 1007  120]
#  [  84 1092  111]
#  [ 375 1177  109]]
# [[  47  670  119]
#  [ 574  755  101]
#  [ 588  840  109]
#  [ 667  925  107]
#  [ 261 1010  120]
#  [  84 1095  111]
#  [ 375 1180  109]]
# [[  47  673  119]
#  [ 574  758  101]
#  [ 588  843  109]
#  [ 667  928  107]
#  [ 261 1013  120]
#  [  84 1098  111]
#  [ 375 1183  109]]
# [[  47  676  119]
#  [ 574  761  101]
#  [ 588  846  109]
#  [ 667  931  107]
#  [ 261 1016  120]
#  [  84 1101  111]
#  [ 375 1186  109]]
# [[  47  679  119]
#  [ 574  764  101]
#  [ 588  849  109]
#  [ 667  934  107]
#  [ 261 1019  120]
#  [  84 1104  111]
#  [ 375 1189  109]]
# [[  47  682  119]
#  [ 574  767  101]
#  [ 588  852  109]
#  [ 667  937  107]
#  [ 261 1022  120]
#  [  84 1107  111]
#  [ 375 1192  109]]
# [[  47  685  119]
#  [ 574  770  101]
#  [ 588  855  109]
#  [ 667  940  107]
#  [ 261 1025  120]
#  [  84 1110  111]
#  [ 375 1195  109]]
# [[  47  688  119]
#  [ 574  773  101]
#  [ 588  858  109]
#  [ 667  943  107]
#  [ 261 1028  120]
# [[ 643  682  115]
#  [ 465  767  109]
#  [ 557  852  102]
#  [ 522  937  115]
#  [   5 1022  112]
#  [ 490 1107  116]
#  [ 197 1192  104]]
# [[ 643  685  115]
#  [ 465  770  109]
#  [ 557  855  102]
#  [ 522  940  115]
#  [   5 1025  112]
#  [ 490 1110  116]
#  [ 197 1195  104]]
# [[ 643  688  115]
#  [ 465  773  109]
#  [ 557  858  102]
#  [ 522  943  115]
#  [   5 1028  112]
#  [ 490 1113  116]
#  [ 197 1198  104]]
# [[ 643  691  115]
#  [ 465  776  109]
#  [ 557  861  102]
#  [ 522  946  115]
#  [   5 1031  112]
#  [ 490 1116  116]
#  [ 197 1201  104]]
# Durchgang 2, Reward: 202, Peak: 0
# [[256  85 110]
#  [614 170 112]
#  [240 255 113]
#  [560 340 105]
#  [400 425 112]
#  [107 510 116]
#  [345 595 104]]
# [[256  88 110]
#  [614 173 112]
#  [240 258 113]
#  [560 343 105]
#  [400 428 112]
#  [107 513 116]
#  [345 598 104]]
# [[256  91 110]
#  [614 176 112]
#  [240 261 113]
#  [560 346 105]
#  [400 431 112]
#  [107 516 116]
#  [345 601 104]]
# [[256  94 110]
#  [614 179 112]
#  [240 264 113]
#  [560 349 105]
#  [400 434 112]
#  [107 519 116]
#  [345 604 104]]
# [[256  97 110]
#  [614 182 112]
#  [240 267 113]
#  [560 352 105]
#  [400 437 112]
#  [107 522 116]
#  [345 607 104]]
# [[256 100 110]
#  [614 185 112]
#  [240 270 113]
#  [560 355 105]
#  [400 440 112]
#  [107 525 116]
#  [345 610 104]]
# [[256 103 110]
#  [614 188 112]
#  [240 273 113]
#  [560 358 105]
#  [400 443 112]
#  [107 528 116]
#  [345 613 104]]
# [[256 106 110]
#  [614 191 112]
#  [240 276 113]
#  [560 361 105]
#  [400 446 112]
#  [107 531 116]
#  [345 616 104]]
# [[256 109 110]
#  [614 194 112]
#  [240 279 113]
#  [560 364 105]
#  [400 449 112]
#  [107 534 116]
#  [345 619 104]]
# [[256 112 110]
#  [614 197 112]
#  [240 282 113]
#  [560 367 105]
#  [400 452 112]
#  [107 537 116]
#  [345 622 104]]
# [[256 115 110]
#  [614 200 112]
#  [240 285 113]
#  [560 370 105]
#  [400 455 112]
#  [107 540 116]
#  [345 625 104]]
# [[256 118 110]
#  [614 203 112]
#  [240 288 113]
#  [560 373 105]
#  [400 458 112]
#  [107 543 116]
#  [345 628 104]]
# [[256 121 110]
#  [614 206 112]
#  [240 291 113]
#  [560 376 105]
#  [400 461 112]
#  [107 546 116]
#  [345 631 104]]
# [[256 124 110]
#  [614 209 112]
#  [240 294 113]
#  [560 379 105]
#  [400 464 112]
#  [107 549 116]
#  [345 634 104]]
# [[256 127 110]
#  [614 212 112]
#  [240 297 113]
#  [560 382 105]
#  [400 467 112]
#  [107 552 116]
#  [345 637 104]]
# [[256 130 110]
#  [614 215 112]
#  [240 300 113]
#  [560 385 105]
#  [400 470 112]
#  [107 555 116]
#  [345 640 104]]
# [[256 133 110]
#  [614 218 112]
#  [240 303 113]
#  [560 388 105]
#  [400 473 112]
#  [107 558 116]
#  [345 643 104]]
# [[256 136 110]
#  [614 221 112]
#  [240 306 113]
#  [560 391 105]
#  [400 476 112]
#  [107 561 116]
#  [345 646 104]]
# [[256 139 110]
#  [614 224 112]
#  [240 309 113]
#  [560 394 105]
#  [400 479 112]
#  [107 564 116]
#  [345 649 104]]
# [[256 142 110]
# ...
# [[502 283 119]
#  [475 368 114]
#  [581 453 104]
#  [538 538 115]
#  [ 53 623 113]
#  [444 708 103]
#  [468 793 106]]
# [[502 286 119]
#  [475 371 114]
#  [581 456 104]
#  [538 541 115]
#  [ 53 626 113]
#  [444 711 103]
#  [468 796 106]]
# [[502 289 119]
#  [475 374 114]
#  [581 459 104]
#  [538 544 115]
#  [ 53 629 113]
#  [444 714 103]
#  [468 799 106]]
# [[502 292 119]
#  [475 377 114]
#  [581 462 104]
#  [538 547 115]
#  [ 53 632 113]
#  [444 717 103]
#  [468 802 106]]
# [[502 295 119]
#  [475 380 114]
#  [581 465 104]
#  [538 550 115]
#  [ 53 635 113]
#  [444 720 103]
#  [468 805 106]]
# [[502 298 119]
#  [475 383 114]
#  [581 468 104]
#  [538 553 115]
#  [ 53 638 113]
#  [444 723 103]
#  [468 808 106]]
# [[502 301 119]
#  [475 386 114]
#  [581 471 104]
#  [538 556 115]
#  [ 53 641 113]
#  [444 726 103]
#  [468 811 106]]
# [[502 304 119]
#  [475 389 114]
#  [581 474 104]
#  [538 559 115]
#  [ 53 644 113]
#  [444 729 103]
#  [468 814 106]]
# [[502 307 119]
#  [475 392 114]
#  [581 477 104]
#  [538 562 115]
#  [ 53 647 113]
#  [444 732 103]
#  [468 817 106]]
# [[502 310 119]
#  [475 395 114]
#  [581 480 104]
#  [538 565 115]
#  [ 53 650 113]
#  [444 735 103]
#  [468 820 106]]
# [[502 313 119]
#  [475 398 114]
#  [581 483 104]
#  [538 568 115]
#  [ 53 653 113]
#  [444 738 103]
#  [468 823 106]]
# [[502 316 119]
#  [475 401 114]
#  [581 486 104]
#  [538 571 115]
#  [ 53 656 113]
#  [444 741 103]
#  [468 826 106]]
# [[502 319 119]
#  [475 404 114]
#  [581 489 104]
#  [538 574 115]
#  [ 53 659 113]
#  [444 744 103]
#  [468 829 106]]
# [[502 322 119]
#  [475 407 114]
#  [581 492 104]
#  [538 577 115]
#  [ 53 662 113]
#  [444 747 103]
#  [468 832 106]]
# [[502 325 119]
#  [475 410 114]
#  [581 495 104]
#  [538 580 115]
#  [ 53 665 113]
#  [444 750 103]
#  [468 835 106]]
# [[502 328 119]
#  [475 413 114]
#  [581 498 104]
#  [538 583 115]
#  [ 53 668 113]
#  [444 753 103]
#  [468 838 106]]
# [[502 331 119]
#  [475 416 114]
#  [581 501 104]
#  [538 586 115]
#  [ 53 671 113]
#  [444 756 103]
#  [468 841 106]]
# [[502 334 119]
#  [475 419 114]
#  [581 504 104]
#  [538 589 115]
#  [ 53 674 113]
#  [444 759 103]
#  [468 844 106]]
# [[502 337 119]
#  [475 422 114]
#  [581 507 104]
#  [538 592 115]
#  [ 53 677 113]
#  [444 762 103]
#  [468 847 106]]
# [[502 340 119]
#  [475 425 114]
#  [581 510 104]
#  [538 595 115]
#  [ 53 680 113]
#  [444 765 103]
#  [468 850 106]]
# [[502 343 119]
#  [475 428 114]
#  [581 513 104]
#  [538 598 115]
#  [ 53 683 113]
#  [444 768 103]
#  [468 853 106]]
# [[502 346 119]
#  [475 431 114]
#  [581 516 104]
#  [538 601 115]
#  [ 53 686 113]
#  [444 771 103]
#  [468 856 106]]
# [[502 349 119]
#  [475 434 114]
#  [581 519 104]
#  [538 604 115]
#  [ 53 689 113]
#  [444 774 103]
#  [468 859 106]]
# [[502 352 119]
#  [475 437 114]
#  [581 522 104]
#  [538 607 115]
#  [ 53 692 113]
#  [444 777 103]
#  [468 862 106]]
# [[502 355 119]
#  [475 440 114]
#  [581 525 104]
#  [538 610 115]
#  [ 53 695 113]
#  [444 780 103]
#  [468 865 106]]
# [[502 358 119]
#  [475 443 114]
#  [581 528 104]
#  [538 613 115]
#  [ 53 698 113]
#  [444 783 103]
#  [468 868 106]]
# [[502 361 119]
#  [475 446 114]
#  [581 531 104]
#  [538 616 115]
#  [ 53 701 113]
#  [444 786 103]
#  [468 871 106]]
# [[502 364 119]
#  [475 449 114]
#  [581 534 104]
#  [538 619 115]
#  [ 53 704 113]
#  [444 789 103]
#  [468 874 106]]
# [[502 367 119]
#  [475 452 114]
#  [581 537 104]
#  [538 622 115]
#  [ 53 707 113]
#  [444 792 103]
#  [468 877 106]]
# [[502 370 119]
#  [475 455 114]
#  [581 540 104]
#  [538 625 115]
#  [ 53 710 113]
#  [444 795 103]
#  [468 880 106]]
# [[502 373 119]
#  [475 458 114]
#  [581 543 104]
#  [538 628 115]
#  [ 53 713 113]
#  [444 798 103]
#  [468 883 106]]
# [[502 376 119]
#  [475 461 114]
#  [581 546 104]
#  [538 631 115]
#  [ 53 716 113]
#  [444 801 103]
#  [468 886 106]]
# [[502 379 119]
#  [475 464 114]
#  [581 549 104]
#  [538 634 115]
#  [ 53 719 113]
#  [444 804 103]
#  [468 889 106]]
# [[502 382 119]
#  [475 467 114]
#  [581 552 104]
#  [538 637 115]
#  [ 53 722 113]
#  [444 807 103]
#  [468 892 106]]
# [[502 385 119]
#  [475 470 114]
#  [581 555 104]
#  [538 640 115]
#  [ 53 725 113]
#  [444 810 103]
#  [468 895 106]]
# [[502 388 119]
#  [475 473 114]
#  [581 558 104]
#  [538 643 115]
#  [ 53 728 113]
#  [444 813 103]
#  [468 898 106]]
# [[502 391 119]
#  [475 476 114]
#  [581 561 104]
#  [538 646 115]
#  [ 53 731 113]
#  [444 816 103]
#  [468 901 106]]
# [[502 394 119]
#  [475 479 114]
#  [581 564 104]
#  [538 649 115]
#  [ 53 734 113]
#  [444 819 103]
#  [468 904 106]]
# [[502 397 119]
#  [475 482 114]
#  [581 567 104]
#  [538 652 115]
#  [ 53 737 113]
#  [444 822 103]
#  [468 907 106]]
# [[502 400 119]
#  [475 485 114]
#  [581 570 104]
#  [538 655 115]
#  [ 53 740 113]
#  [444 825 103]
#  [468 910 106]]
# [[502 403 119]
#  [475 488 114]
#  [581 573 104]
#  [538 658 115]
#  [ 53 743 113]
#  [444 828 103]
#  [468 913 106]]
# [[502 406 119]
#  [475 491 114]
#  [581 576 104]
#  [538 661 115]
#  [ 53 746 113]
#  [444 831 103]
#  [468 916 106]]
# [[502 409 119]
#  [475 494 114]
#  [581 579 104]
#  [538 664 115]
#  [ 53 749 113]
#  [444 834 103]
#  [468 919 106]]
# [[502 412 119]
#  [475 497 114]
#  [581 582 104]
#  [538 667 115]
#  [ 53 752 113]
#  [444 837 103]
#  [468 922 106]]
# [[502 415 119]
#  [475 500 114]
#  [581 585 104]
#  [538 670 115]
#  [ 53 755 113]
#  [444 840 103]
#  [468 925 106]]
# [[502 418 119]
#  [475 503 114]
#  [581 588 104]
#  [538 673 115]
#  [ 53 758 113]
#  [444 843 103]
#  [468 928 106]]
# [[502 421 119]
#  [475 506 114]
#  [581 591 104]
#  [538 676 115]
#  [ 53 761 113]
#  [444 846 103]
#  [468 931 106]]
# [[502 424 119]
#  [475 509 114]
#  [581 594 104]
#  [538 679 115]
#  [ 53 764 113]
#  [444 849 103]
#  [468 934 106]]
# [[502 427 119]
#  [475 512 114]
#  [581 597 104]
#  [538 682 115]
#  [ 53 767 113]
#  [444 852 103]
#  [468 937 106]]
# [[502 430 119]
#  [475 515 114]
#  [581 600 104]
#  [538 685 115]
#  [ 53 770 113]
#  [444 855 103]
#  [468 940 106]]
# [[502 433 119]
#  [475 518 114]
#  [581 603 104]
#  [538 688 115]
#  [ 53 773 113]
#  [444 858 103]
#  [468 943 106]]
# [[502 436 119]
#  [475 521 114]
#  [581 606 104]
#  [538 691 115]
#  [ 53 776 113]
#  [444 861 103]
#  [468 946 106]]
# [[502 439 119]
#  [475 524 114]
#  [581 609 104]
#  [538 694 115]
#  [ 53 779 113]
#  [444 864 103]
#  [468 949 106]]
# [[502 442 119]
#  [475 527 114]
#  [581 612 104]
#  [538 697 115]
#  [ 53 782 113]
#  [444 867 103]
#  [468 952 106]]
# [[502 445 119]
#  [475 530 114]
#  [581 615 104]
#  [538 700 115]
#  [ 53 785 113]
#  [444 870 103]
#  [468 955 106]]
# [[502 448 119]
#  [475 533 114]
#  [581 618 104]
#  [538 703 115]
#  [ 53 788 113]
#  [444 873 103]
#  [468 958 106]]
# [[502 451 119]
#  [475 536 114]
#  [581 621 104]
#  [538 706 115]
#  [ 53 791 113]
#  [444 876 103]
#  [468 961 106]]
# [[502 454 119]
#  [475 539 114]
#  [581 624 104]
#  [538 709 115]
#  [ 53 794 113]
#  [444 879 103]
#  [468 964 106]]
# [[502 457 119]
#  [475 542 114]
#  [581 627 104]
#  [538 712 115]
#  [ 53 797 113]
#  [444 882 103]
#  [468 967 106]]
# [[502 460 119]
#  [475 545 114]
#  [581 630 104]
#  [538 715 115]
#  [ 53 800 113]
#  [444 885 103]
#  [468 970 106]]
# [[502 463 119]
#  [475 548 114]
#  [581 633 104]
#  [538 718 115]
#  [ 53 803 113]
#  [444 888 103]
#  [468 973 106]]
# [[502 466 119]
#  [475 551 114]
#  [581 636 104]
#  [538 721 115]
#  [ 53 806 113]
#  [444 891 103]
#  [468 976 106]]
# [[502 469 119]
#  [475 554 114]
#  [581 639 104]
#  [538 724 115]
#  [ 53 809 113]
#  [444 894 103]
#  [468 979 106]]
# [[502 472 119]
#  [475 557 114]
#  [581 642 104]
#  [538 727 115]
#  [ 53 812 113]
#  [444 897 103]
#  [468 982 106]]
# [[502 475 119]
#  [475 560 114]
#  [581 645 104]
#  [538 730 115]
#  [ 53 815 113]
#  [444 900 103]
#  [468 985 106]]
# [[502 478 119]
#  [475 563 114]
#  [581 648 104]
#  [538 733 115]
#  [ 53 818 113]
#  [444 903 103]
#  [468 988 106]]
# [[502 481 119]
#  [475 566 114]
#  [581 651 104]
#  [538 736 115]
#  [ 53 821 113]
#  [444 906 103]
#  [468 991 106]]
# [[502 484 119]
#  [475 569 114]
#  [581 654 104]
#  [538 739 115]
#  [ 53 824 113]
#  [444 909 103]
#  [468 994 106]]
# [[502 487 119]
#  [475 572 114]
#  [581 657 104]
#  [538 742 115]
#  [ 53 827 113]
#  [444 912 103]
#  [468 997 106]]
# [[ 502  490  119]
#  [ 475  575  114]
#  [ 581  660  104]
#  [ 538  745  115]
#  [  53  830  113]
#  [ 444  915  103]
#  [ 468 1000  106]]
# [[ 502  493  119]
#  [ 475  578  114]
#  [ 581  663  104]
#  [ 538  748  115]
#  [  53  833  113]
#  [ 444  918  103]
#  [ 468 1003  106]]
# [[ 502  496  119]
#  [ 475  581  114]
#  [ 581  666  104]
#  [ 538  751  115]
#  [  53  836  113]
#  [ 444  921  103]
#  [ 468 1006  106]]
# [[ 502  499  119]
#  [ 475  584  114]
#  [ 581  669  104]
#  [ 538  754  115]
#  [  53  839  113]
#  [ 444  924  103]
#  [ 468 1009  106]]
# [[ 502  502  119]
#  [ 475  587  114]
#  [ 581  672  104]
#  [ 538  757  115]
#  [  53  842  113]
#  [ 444  927  103]
#  [ 468 1012  106]]
# [[ 502  505  119]
#  [ 475  590  114]
#  [ 581  675  104]
#  [ 538  760  115]
#  [  53  845  113]
#  [ 444  930  103]
#  [ 468 1015  106]]
# [[ 502  508  119]
#  [ 475  593  114]
#  [ 581  678  104]
#  [ 538  763  115]
#  [  53  848  113]
#  [ 444  933  103]
#  [ 468 1018  106]]
# [[ 502  511  119]
#  [ 475  596  114]
#  [ 581  681  104]
#  [ 538  766  115]
#  [  53  851  113]
#  [ 444  936  103]
#  [ 468 1021  106]]
# [[ 502  514  119]
#  [ 475  599  114]
#  [ 581  684  104]
#  [ 538  769  115]
#  [  53  854  113]
#  [ 444  939  103]
#  [ 468 1024  106]]
# [[ 502  517  119]
#  [ 475  602  114]
#  [ 581  687  104]
#  [ 538  772  115]
#  [  53  857  113]
#  [ 444  942  103]
#  [ 468 1027  106]]
# [[ 502  520  119]
#  [ 475  605  114]
#  [ 581  690  104]
#  [ 538  775  115]
#  [  53  860  113]
#  [ 444  945  103]
#  [ 468 1030  106]]
# [[ 502  523  119]
#  [ 475  608  114]
#  [ 581  693  104]
#  [ 538  778  115]
#  [  53  863  113]
#  [ 444  948  103]
#  [ 468 1033  106]]
# [[ 502  526  119]
#  [ 475  611  114]
#  [ 581  696  104]
#  [ 538  781  115]
#  [  53  866  113]
#  [ 444  951  103]
#  [ 468 1036  106]]
# [[ 502  529  119]
#  [ 475  614  114]
#  [ 581  699  104]
#  [ 538  784  115]
#  [  53  869  113]
#  [ 444  954  103]
#  [ 468 1039  106]]
# [[ 502  532  119]
#  [ 475  617  114]
#  [ 581  702  104]
#  [ 538  787  115]
#  [  53  872  113]
#  [ 444  957  103]
#  [ 468 1042  106]]
# [[ 502  535  119]
#  [ 475  620  114]
#  [ 581  705  104]
#  [ 538  790  115]
#  [  53  875  113]
#  [ 444  960  103]
#  [ 468 1045  106]]
# [[ 502  538  119]
#  [ 475  623  114]
#  [ 581  708  104]
#  [ 538  793  115]
#  [  53  878  113]
#  [ 444  963  103]
#  [ 468 1048  106]]
# [[ 502  541  119]
#  [ 475  626  114]
#  [ 581  711  104]
#  [ 538  796  115]
#  [  53  881  113]
#  [ 444  966  103]
#  [ 468 1051  106]]
# [[ 502  544  119]
#  [ 475  629  114]
#  [ 581  714  104]
#  [ 538  799  115]
#  [  53  884  113]
#  [ 444  969  103]
#  [ 468 1054  106]]
# [[ 502  547  119]
#  [ 475  632  114]
#  [ 581  717  104]
#  [ 538  802  115]
#  [  53  887  113]
#  [ 444  972  103]
#  [ 468 1057  106]]
# [[ 502  550  119]
#  [ 475  635  114]
#  [ 581  720  104]
#  [ 538  805  115]
#  [  53  890  113]
#  [ 444  975  103]
#  [ 468 1060  106]]
# [[ 502  553  119]
#  [ 475  638  114]
#  [ 581  723  104]
#  [ 538  808  115]
#  [  53  893  113]
#  [ 444  978  103]
#  [ 468 1063  106]]
# [[ 502  556  119]
#  [ 475  641  114]
#  [ 581  726  104]
#  [ 538  811  115]
#  [  53  896  113]
#  [ 444  981  103]
#  [ 468 1066  106]]
# [[ 502  559  119]
#  [ 475  644  114]
#  [ 581  729  104]
#  [ 538  814  115]
#  [  53  899  113]
#  [ 444  984  103]
#  [ 468 1069  106]]
# [[ 502  562  119]
#  [ 475  647  114]
#  [ 581  732  104]
#  [ 538  817  115]
#  [  53  902  113]
#  [ 444  987  103]
#  [ 468 1072  106]]
# [[ 502  565  119]
#  [ 475  650  114]
#  [ 581  735  104]
#  [ 538  820  115]
#  [  53  905  113]
#  [ 444  990  103]
#  [ 468 1075  106]]
# [[ 502  568  119]
#  [ 475  653  114]
#  [ 581  738  104]
#  [ 538  823  115]
#  [  53  908  113]
#  [ 444  993  103]
#  [ 468 1078  106]]
# [[ 502  571  119]
#  [ 475  656  114]
#  [ 581  741  104]
#  [ 538  826  115]
#  [  53  911  113]
#  [ 444  996  103]
#  [ 468 1081  106]]
# [[ 502  574  119]
#  [ 475  659  114]
#  [ 581  744  104]
#  [ 538  829  115]
#  [ 538  883  115]
#  [  53  968  113]
#  [ 444 1053  103]
#  [ 468 1138  106]]
# [[ 502  631  119]
#  [ 475  716  114]
#  [ 581  801  104]
#  [ 538  886  115]
#  [  53  971  113]
#  [ 444 1056  103]
#  [ 468 1141  106]]
# [[ 502  634  119]
#  [ 475  719  114]
#  [ 581  804  104]
#  [ 538  889  115]
#  [  53  974  113]
#  [ 444 1059  103]
#  [ 468 1144  106]]
# [[ 502  637  119]
#  [ 475  722  114]
#  [ 581  807  104]
#  [ 538  892  115]
#  [  53  977  113]
#  [ 444 1062  103]
#  [ 468 1147  106]]
# [[ 502  640  119]
#  [ 475  725  114]
#  [ 581  810  104]
#  [ 538  895  115]
#  [  53  980  113]
#  [ 444 1065  103]
#  [ 468 1150  106]]
# [[ 502  643  119]
#  [ 475  728  114]
#  [ 581  813  104]
#  [ 538  898  115]
#  [  53  983  113]
#  [ 444 1068  103]
#  [ 468 1153  106]]
# [[ 502  646  119]
#  [ 475  731  114]
#  [ 581  816  104]
#  [ 538  901  115]
#  [  53  986  113]
#  [ 444 1071  103]
#  [ 468 1156  106]]
# [[ 502  649  119]
#  [ 475  734  114]
#  [ 581  819  104]
#  [ 538  904  115]
#  [  53  989  113]
#  [ 444 1074  103]
#  [ 468 1159  106]]
# [[ 502  652  119]
#  [ 475  737  114]
#  [ 581  822  104]
#  [ 538  907  115]
#  [  53  992  113]
#  [ 444 1077  103]
#  [ 468 1162  106]]
# [[ 502  655  119]
#  [ 475  740  114]
#  [ 581  825  104]
#  [ 538  910  115]
#  [  53  995  113]
#  [ 444 1080  103]
#  [ 468 1165  106]]
# [[ 502  658  119]
#  [ 475  743  114]
#  [ 581  828  104]
#  [ 538  913  115]
#  [  53  998  113]
#  [ 444 1083  103]
#  [ 468 1168  106]]
# [[ 502  661  119]
#  [ 475  746  114]
#  [ 581  831  104]
#  [ 538  916  115]
#  [  53 1001  113]
#  [ 444 1086  103]
#  [ 468 1171  106]]
# [[ 502  664  119]
#  [ 475  749  114]
#  [ 581  834  104]
#  [ 538  919  115]
#  [  53 1004  113]
#  [ 444 1089  103]
#  [ 468 1174  106]]
# [[ 502  667  119]
#  [ 475  752  114]
#  [ 581  837  104]
#  [ 538  922  115]
#  [  53 1007  113]
#  [ 444 1092  103]
#  [ 468 1177  106]]
# [[ 502  670  119]
#  [ 475  755  114]
#  [ 581  840  104]
#  [ 538  925  115]
#  [  53 1010  113]
#  [ 444 1095  103]
#  [ 468 1180  106]]
# [[ 502  673  119]
#  [ 475  758  114]
#  [ 581  843  104]
#  [ 538  928  115]
#  [  53 1013  113]
#  [ 444 1098  103]
#  [ 468 1183  106]]
# [[ 502  676  119]
#  [ 475  761  114]
#  [ 581  846  104]
#  [ 538  931  115]
#  [  53 1016  113]
#  [ 444 1101  103]
#  [ 468 1186  106]]
# [[ 502  679  119]
#  [ 475  764  114]
#  [ 581  849  104]
#  [ 538  934  115]
#  [  53 1019  113]
#  [ 444 1104  103]
#  [ 468 1189  106]]
# [[ 502  682  119]
#  [ 475  767  114]
#  [ 581  852  104]
#  [ 538  937  115]
#  [  53 1022  113]
#  [ 444 1107  103]
#  [ 468 1192  106]]
# [[ 502  685  119]
#  [ 475  770  114]
#  [ 581  855  104]
#  [ 538  940  115]
#  [  53 1025  113]
#  [ 444 1110  103]
#  [ 468 1195  106]]
# [[ 502  688  119]
#  [ 475  773  114]
#  [ 581  858  104]
#  [ 538  943  115]
#  [  53 1028  113]
#  [ 444 1113  103]
#  [ 468 1198  106]]
# [[ 502  691  119]
#  [ 475  776  114]
#  [ 581  861  104]
#  [ 538  946  115]
#  [  53 1031  113]
#  [ 444 1116  103]
#  [ 468 1201  106]]
# Durchgang 10, Reward: 202, Peak: 0

# %%
from stable_baselines3 import PPO

# %%
env = DoodleJumpPlayer()

model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100_000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1735 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3e+03        |
# |    ep_rew_mean          | 3e+03        |
# | time/                   |              |
# |    fps                  | 907          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0022882232 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | -0.1         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.81         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 88.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.9e+03     |
# |    ep_rew_mean          | 1.9e+03     |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009676749 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.62e+03    |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008860765 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | 0.0537      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 105         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 928          |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 5            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0117423115 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | 0.00257      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 90           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 808          |
# |    ep_rew_mean          | 808          |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0044083335 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.00784      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 82.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 736         |
# |    ep_rew_mean          | 736         |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011320988 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.0335      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 71.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 729         |
# | time/                   |             |
# |    fps                  | 672         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011515465 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0999      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 67.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 656        |
# |    ep_rew_mean          | 656        |
# | time/                   |            |
# |    fps                  | 662        |
# |    iterations           | 9          |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00908699 |
# |    clip_fraction        | 0.0541     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.644     |
# |    explained_variance   | 0.00979    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.41       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00112   |
# |    value_loss           | 56.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 620         |
# | time/                   |             |
# |    fps                  | 656         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004972129 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 81.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 616          |
# |    ep_rew_mean          | 616          |
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 11           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0060533537 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.0943       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.3         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 75.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | 603         |
# | time/                   |             |
# |    fps                  | 640         |
# |    iterations           | 12          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006232381 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.0256      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00214    |
# |    value_loss           | 55          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 577          |
# |    ep_rew_mean          | 577          |
# | time/                   |              |
# |    fps                  | 634          |
# |    iterations           | 13           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0046906015 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.627       |
# |    explained_variance   | 0.171        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 59.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 562         |
# |    ep_rew_mean          | 562         |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 14          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008383951 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 81.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 553          |
# |    ep_rew_mean          | 553          |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 15           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0052216644 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.367        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.1         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 63.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 548          |
# |    ep_rew_mean          | 548          |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 16           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0057103937 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | 0.411        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000391    |
# |    value_loss           | 70.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 543          |
# |    ep_rew_mean          | 543          |
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 17           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0044156164 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 41           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 526          |
# |    ep_rew_mean          | 526          |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 18           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0059942342 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.65        |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 59.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 520          |
# |    ep_rew_mean          | 520          |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 19           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0046082297 |
# |    clip_fraction        | 0.00776      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -1.4e-05     |
# |    value_loss           | 44           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 522          |
# |    ep_rew_mean          | 522          |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 20           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0057335338 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.67        |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.47         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 43.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 524         |
# |    ep_rew_mean          | 524         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 21          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007539576 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 36.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 524          |
# |    ep_rew_mean          | 524          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 22           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0077569853 |
# |    clip_fraction        | 0.088        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 31.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 527          |
# |    ep_rew_mean          | 527          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 23           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0029950603 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.667       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.21         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000175    |
# |    value_loss           | 46.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 534          |
# |    ep_rew_mean          | 534          |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 24           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0073292423 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.644       |
# |    explained_variance   | 0.82         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.29         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 30.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 530         |
# |    ep_rew_mean          | 530         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 25          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.002354352 |
# |    clip_fraction        | 0.0214      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000313   |
# |    value_loss           | 56.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 485         |
# |    ep_rew_mean          | 485         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 26          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004960968 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.41        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 39.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 464          |
# |    ep_rew_mean          | 464          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 27           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0030931483 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 51.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | 468         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 28          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005574734 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000665   |
# |    value_loss           | 56.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 468        |
# |    ep_rew_mean          | 468        |
# | time/                   |            |
# |    fps                  | 583        |
# |    iterations           | 29         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00676441 |
# |    clip_fraction        | 0.0913     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.619     |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.3       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.00266    |
# |    value_loss           | 43.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 477         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 30          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007678607 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 31.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 484         |
# |    ep_rew_mean          | 484         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 31          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007230936 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.000185   |
# |    value_loss           | 42          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 483         |
# |    ep_rew_mean          | 483         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 32          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004122319 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.000337    |
# |    value_loss           | 25.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | 493         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 33          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006377649 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00102     |
# |    value_loss           | 43.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 34           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0049933908 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.644       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.3         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.00131      |
# |    value_loss           | 65.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 502         |
# |    ep_rew_mean          | 502         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 35          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009117764 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.2        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 57.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 508          |
# |    ep_rew_mean          | 508          |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 36           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039035704 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.638       |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.3         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 49           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 521         |
# |    ep_rew_mean          | 521         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 37          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003224823 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.3         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 34.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 519         |
# |    ep_rew_mean          | 519         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 38          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020199142 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.89        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00181     |
# |    value_loss           | 15.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 539         |
# |    ep_rew_mean          | 539         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 39          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004743422 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000468   |
# |    value_loss           | 24.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 543          |
# |    ep_rew_mean          | 543          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 40           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0027062488 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.75         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000162    |
# |    value_loss           | 42.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 544          |
# |    ep_rew_mean          | 544          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 41           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0059101656 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.65         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 38.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 548          |
# |    ep_rew_mean          | 548          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 42           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0063030855 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.53         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 42.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 540         |
# |    ep_rew_mean          | 540         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 43          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007139434 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 60          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 540          |
# |    ep_rew_mean          | 540          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 44           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0035546673 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.1         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 41.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 547          |
# |    ep_rew_mean          | 547          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 45           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0023924508 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.78         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000467     |
# |    value_loss           | 32.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 542         |
# |    ep_rew_mean          | 542         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 46          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003193372 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.47        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.000601   |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 539         |
# |    ep_rew_mean          | 539         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 47          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010750411 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.000508    |
# |    value_loss           | 39.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 534          |
# |    ep_rew_mean          | 534          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 48           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0019272675 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.635       |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.51         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000247    |
# |    value_loss           | 29.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 538         |
# |    ep_rew_mean          | 538         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 49          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006957868 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.618      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00108     |
# |    value_loss           | 20.8        |
# -----------------------------------------

# %%
model.save("Models/DoodleJump")

# %%
env = DoodleJumpPlayer()
model = PPO.load("Models/DoodleJump", env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
durchgaenge = 10
for x in range(durchgaenge):
    observation = env.reset()  # Umgebung auf den Anfangszustand zurücksetzen
    score = 0  # Variable um die Performance des Algorithmus' zu speichern
    done = False  # Beschreibt, ob der Agent noch "im Spiel" ist
    observation = observation[0]

    while not done:
        env.render()
        
        # Jetzt nehmen wir anstatt einer Random Action die Vorhersage des Models
        action, _ = model.predict(observation)
        if action.ndim == 1:
            action = action[0]
        
        observation, reward, done, term, info = env.step(action)
        score += reward  # reward: Gibt dem Agenten für korrekte Aktionen +Punkte, oder keine Punkte

    print(f"Durchgang {x + 1}, Score: {score}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 12
#       9 env.render()
#      11 # Jetzt nehmen wir anstatt einer Random Action die Vorhersage des Models
# ---> 12 action, _ = model.predict(observation)
#      13 if action.ndim == 1:
#      14     action = action[0]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)
#     362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\utils.py:401, in is_vectorized_observation(observation, observation_space)
#     399 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     400     if isinstance(observation_space, space_type):
# --> 401         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     402 else:
#     403     # for-else happens if no break is called
#     404     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\utils.py:268, in is_vectorized_box_observation(observation, observation_space)
#     266     return True
#     267 else:
# --> 268     raise ValueError(
#     269         f"Error: Unexpected observation shape {observation.shape} for "
#     270         + f"Box environment, please use {observation_space.shape} "
#     271         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     272     )
#
# ValueError: Error: Unexpected observation shape (26,) for Box environment, please use (23,) or (n_env, 23) for the observation shape.
